# %% [markdown]
# ## __Data Science: Capstone Part 1: Lightning Talk 1__

# %% [markdown]
# ### Overview
#
# In the field of data science, good projects are practical. Your capstone project should be manageable and affect a real world audience. This might be a domain you are familiar with, a particular interest you have, something that affects a community you are involved in, or an area that relates to a field you wish to work in.
#
# One of the best ways to test ideas quickly is to share them with others. A good data scientist has to be comfortable discussing ideas and presenting to audiences. That's why for Part 1 of your Capstone project, you'll be preparing a lightning talk on some potential interest areas and datasets.
#
# This deliverable will provide you with guidance to help you select an awesome topic and begin to build a polished Capstone project.
#
#
#
# __Goal__: Host a lightning talk presentation describing at least three project proposals, including associated data, problem statement, goals, approach, and basic EDA.

# %% [markdown]
# ### REQUIRED
#
# __Foreach Topic__:
# - Problem Statement
# - Goals
# - Approach
# - Data Source(s)
# - Data Info. (basic EDA)
#
# Dataset should have __15k+__ rows and __10+__ columns
#
# ___Remember, if you can't find data to support your topic, then you can't move forward.___

# %% [markdown]
# # Topic 1 : Personalized Learning Through Student Behavior Clustering Using ASSISTments Data

# %% [markdown]
# ## Problem Statement
#
# Online learning platforms such as ASSISTments collect rich data about student interactions, including response accuracy, response time, attempts, and hint usage. However, students often receive similar learning experiences despite having different learning behaviors.
#
# This project applies clustering techniques to group students with similar learning behaviors and generate meaningful learning profiles. These profiles can help educators and intelligent tutoring systems provide personalized learning experiences, targeted interventions, and data-driven instructional support to improve student outcomes.

# %% [markdown]
# ## Data Info
# Data Source : https://sites.google.com/site/assistmentsdata/home/2009-2010-assistment-data/skill-builder-data-2009-2010

# %% [markdown]
# ## Data Dictionary
#
# | Feature | Data Type | Description |
# |---------|----------|-------------|
# | **order_id** | Integer | Chronological identifier of the student's interaction. Larger values indicate later interactions. |
# | **assignment_id** | Integer | Unique identifier of the assignment (homework or activity) created by a teacher for a class. Different teachers can assign the same content but have different assignment IDs. |
# | **user_id** | Integer | Unique identifier for each student. |
# | **assistment_id** | Integer | Identifier of the ASSISTment (tutoring activity). One ASSISTment may contain multiple related problems or scaffold questions. |
# | **problem_id** | Integer | Unique identifier for an individual problem. |
# | **original** | Binary (0/1) | Indicates whether the problem is the original question (`1`) or a scaffold/help question (`0`). |
# | **correct** | Binary (0/1) | Indicates whether the student answered correctly on the first attempt (`1`) or answered incorrectly/requested help (`0`). This is commonly used as the target variable. |
# | **attempt_count** | Integer | Number of attempts the student made before completing the problem. |
# | **ms_first_response** | Integer | Time (in milliseconds) between displaying the problem and the student's first response. |
# | **tutor_mode** | Categorical | Learning mode during the interaction. Possible values include `tutor`and `test` |
# | **answer_type** | Categorical | Type of expected answer (e.g., `choose_1`, `algebra`, `fill_in`, `open_response`). |
# | **sequence_id** | Integer | Identifier of the problem set. Multiple assignments can share the same sequence if they use the same problem set. |
# | **student_class_id** | Integer | Identifier of the student's classroom or class section. |
# | **position** | Integer | Position of the assignment on the student's assignment page. |
# | **problem_set_type** | Categorical | Organization of the problem set. Possible values include `Linear`, `Random`, and `Mastery`. |
# | **base_sequence_id** | Integer | Identifier of the original sequence from which the current sequence was copied. If not copied, it is equal to `sequence_id`. |
# | **skill_id** | Integer | Identifier of the mathematical skill associated with the problem. In the Skill Builder dataset, each row contains only one skill. Multi-skill problems are duplicated into multiple rows. |
# | **skill_name** | String | Name of the mathematical skill associated with the problem. |
# | **teacher_id** | Integer | Unique identifier of the teacher who assigned the problem. |
# | **school_id** | Integer | Unique identifier of the school. |
# | **hint_count** | Integer | Number of hints requested by the student while solving the problem. |
# | **hint_total** | Integer | Total number of hints available for the problem. |
# | **overlap_time** | Integer | Time (in milliseconds) representing overlapping student activity while interacting with the problem. |
# | **template_id** | Integer | Identifier of the ASSISTment template. Problems sharing the same template have similar structures but different values. |
# | **answer_id** | Integer | Identifier of the selected answer for multiple-choice questions. |
# | **answer_text** | String | Student's submitted answer for fill-in or text-based questions. |
# | **first_action** | Categorical | Student's first action after viewing the problem, such as `attempt` or `hint`. |
# | **bottom_hint** | Binary (0/1) | Indicates whether the student requested the bottom-out hint (the final hint revealing the solution). |
# | **opportunity** | Integer | Number of previous opportunities the student has had to practice the associated skill. |
# | **opportunity_original** | Integer | Number of previous opportunities the student has had to practice the skill considering only original problems (`original = 1`). |
#
# ---
#
# # Target Variable
#
# | Feature | Description |
# |---------|-------------|
# | **correct** | Binary target variable indicating whether the student answered the problem correctly on the first attempt. `1` = Correct, `0` = Incorrect or requested help. |
#
# ---
#
# # Feature Categories
#
# | Category | Features |
# |----------|----------|
# | **Student Information** | `user_id`, `student_class_id`, `teacher_id`, `school_id` |
# | **Assignment Information** | `assignment_id`, `sequence_id`, `base_sequence_id`, `position`, `problem_set_type` |
# | **Problem Information** | `assistment_id`, `problem_id`, `template_id`, `original` |
# | **Skill Information** | `skill_id`, `skill_name`, `opportunity`, `opportunity_original` |
# | **Student Behavior** | `attempt_count`, `hint_count`, `hint_total`, `ms_first_response`, `overlap_time`, `first_action`, `bottom_hint` |
# | **Response Information** | `correct`, `answer_type`, `answer_id`, `answer_text` |
#
# ---
#
# # Notes
#
# - **`correct`** is the primary target variable used in most machine learning tasks on this dataset.
# - The **Skill Builder** version stores **one skill per row**. If a problem assesses multiple skills, the interaction is duplicated so that each row corresponds to a single skill.
# - Time-related features (`ms_first_response`, `overlap_time`) are measured in **milliseconds (ms)**.
# - Columns ending with `_id` are identifiers and generally should not be treated as continuous numerical variables. Depending on the modeling approach, they may be removed, encoded, or used for grouping.
# - `opportunity` and `opportunity_original` are important educational features because they measure how many times a student has previously practiced a skill, making them valuable predictors of student mastery.

# %%
# start you EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# %% [markdown]
# #### What is your target column and what does it represent?
# **Target Column:** None
#
# **Representation:** This project uses an **unsupervised learning (clustering)** approach, so there is no target column. Instead, the model groups students based on similarities in their learning behaviors, such as response accuracy, response time, number of attempts, hint usage, and practice opportunities. The resulting clusters represent different student learning profiles that can be used to support personalized learning experiences.

# %%
df = pd.read_csv('data/skill_builder_data_corrected_collapsed.csv', encoding='latin-1')
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_26160\102637691.py:1: DtypeWarning: Columns (0: skill_id, 1: skill_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/skill_builder_data_corrected_collapsed.csv', encoding='latin-1')

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    Unnamed: 0  order_id  assignment_id  user_id  assistment_id  problem_id  \
# 0           1  33022537         277618    64525          33139       51424
# 1           2  33022709         277618    64525          33150       51435
# 2           3  35450204         220674    70363          33159       51444
# 3           4  35450295         220674    70363          33110       51395
# 4           5  35450311         220674    70363          33196       51481
#
#    original  correct  attempt_count  ms_first_response tutor_mode answer_type  \
# 0         1        1              1              32454      tutor     algebra
# 1         1        1              1               4922      tutor     algebra
# 2         1        0              2              25390      tutor     algebra
# 3         1        1              1               4859      tutor     algebra
# 4         1        0             14              19813      tutor     algebra
#
#    sequence_id  student_class_id  position            type  base_sequence_id  \
# 0         5948             13241       126  MasterySection              5948
# 1         5948             13241       126  MasterySection              5948
# 2         5948             11816        22  MasterySection              5948
# 3         5948             11816        22  MasterySection              5948
# 4         5948             11816        22  MasterySection              5948
#
#   skill_id       skill_name  teacher_id  school_id  hint_count  hint_total  \
# 0     1_13  Box and Whisker       22763         73           0           3
# 1     1_13  Box and Whisker       22763         73           0           3
# 2     1_13  Box and Whisker       22763         73           0           3
# 3     1_13  Box and Whisker       22763         73           0           3
# 4     1_15  Box and Whisker       22763         73           3           4
#
#    overlap_time  template_id  answer_id answer_text  first_action  \
# 0         32454        30799        NaN          26             0
# 1          4922        30799        NaN          55             0
# 2         42000        30799        NaN          88             0
# 3          4859        30059        NaN          41             0
# 4        124564        30060        NaN          65             0
#
#    bottom_hint  opportunity  opportunity_original
# 0          NaN            1                   1.0
# 1          NaN            2                   2.0
# 2          NaN            1                   1.0
# 3          NaN            2                   2.0
# 4          0.0            3                   3.0

# %%
df.shape
# Out:
# (346860, 31)

# %% [markdown]
# #### Is your target categorical or continuous? is it balanced (Plot the distribution)? categorical, Not balance
#
# This project uses an **unsupervised learning (clustering)** approach, so there is no target variable to classify as categorical or continuous. Consequently, target class balance and target distribution are not applicable. Instead, the analysis focuses on the distribution of the input features used to group students into learning profiles.

# %% [markdown]
# #### What types of features do you have (categorical / numerical)? how many of each ?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'assignment_id', 'user_id', 'assistment_id',
#        'problem_id', 'original', 'correct', 'attempt_count',
#        'ms_first_response', 'tutor_mode', 'answer_type', 'sequence_id',
#        'student_class_id', 'position', 'type', 'base_sequence_id', 'skill_id',
#        'skill_name', 'teacher_id', 'school_id', 'hint_count', 'hint_total',
#        'overlap_time', 'template_id', 'answer_id', 'answer_text',
#        'first_action', 'bottom_hint', 'opportunity', 'opportunity_original'],
#       dtype='str')

# %%
df['skill_name'].value_counts()
# Out:
# skill_name
# Equation Solving Two or Fewer Steps         24253
# Conversion of Fraction Decimals Percents    18742
# Addition and Subtraction Integers           12741
# Addition and Subtraction Fractions          11334
# Equation Solving More Than Two Steps         8115
#                                             ...
# Distributive Property                          18
# Finding Slope From Situation                    9
# Recognize Quadratic Pattern                     8
# Reading a Ruler or Scale                        5
# Finding Slope from Ordered Pairs                5
# Name: count, Length: 101, dtype: int64

# %%
df['tutor_mode'].value_counts()
# Out:
# tutor_mode
# tutor    346601
# test        259
# Name: count, dtype: int64

# %%
df['answer_type'].value_counts()
# Out:
# answer_type
# algebra          270780
# choose_1          41181
# fill_in_1         34786
# choose_n            105
# open_response         8
# Name: count, dtype: int64

# %%
df['first_action'].value_counts()
# Out:
# first_action
# 0    309271
# 1     31273
# 2      6316
# Name: count, dtype: int64

# %%
df['bottom_hint'].value_counts()
# Out:
# bottom_hint
# 1.0    42932
# 0.0    16925
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 346860 entries, 0 to 346859
# Data columns (total 31 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            346860 non-null  int64
#  1   order_id              346860 non-null  int64
#  2   assignment_id         346860 non-null  int64
#  3   user_id               346860 non-null  int64
#  4   assistment_id         346860 non-null  int64
#  5   problem_id            346860 non-null  int64
#  6   original              346860 non-null  int64
#  7   correct               346860 non-null  int64
#  8   attempt_count         346860 non-null  int64
#  9   ms_first_response     346860 non-null  int64
#  10  tutor_mode            346860 non-null  str
#  11  answer_type           346860 non-null  str
#  12  sequence_id           346860 non-null  int64
#  13  student_class_id      346860 non-null  int64
#  14  position              346860 non-null  int64
#  15  type                  346860 non-null  str
#  16  base_sequence_id      346860 non-null  int64
#  17  skill_id              283105 non-null  object
#  18  skill_name            274590 non-null  str
#  19  teacher_id            346860 non-null  int64
#  20  school_id             346860 non-null  int64
#  21  hint_count            346860 non-null  int64
#  22  hint_total            346860 non-null  int64
#  23  overlap_time          346860 non-null  int64
#  24  template_id           346860 non-null  int64
#  25  answer_id             40042 non-null   float64
#  26  answer_text           269230 non-null  str
#  27  first_action          346860 non-null  int64
#  28  bottom_hint           59857 non-null   float64
#  29  opportunity           346860 non-null  int64
#  30  opportunity_original  275458 non-null  float64
# dtypes: float64(3), int64(22), object(1), str(5)
# memory usage: 98.3+ MB

# %%
# df.drop(columns=['Unnamed: 0', 'tutor_mode', 'position', 'teacher_id', 'school_id', 'bottom_hint','answer_text','answer_id'], inplace=True)

# %% [markdown]
# ## Feature Types
#
# The dataset contains **31 features**, which can be categorized as follows:
#
# ### Categorical Features (5)
#
# - `tutor_mode`
# - `answer_type`
# - `type`
# - `skill_name`
# - `answer_text`
#
# ### Numerical Features (26)
#
# - `Unnamed: 0`
# - `order_id`
# - `assignment_id`
# - `user_id`
# - `assistment_id`
# - `problem_id`
# - `original`
# - `correct`
# - `attempt_count`
# - `ms_first_response`
# - `sequence_id`
# - `student_class_id`
# - `position`
# - `base_sequence_id`
# - `skill_id`
# - `teacher_id`
# - `school_id`
# - `hint_count`
# - `hint_total`
# - `overlap_time`
# - `template_id`
# - `answer_id`
# - `first_action`
# - `bottom_hint`
# - `opportunity`
# - `opportunity_original`
#
# > **Note:** Several numerical columns (e.g., `user_id`, `problem_id`, `skill_id`, `teacher_id`, and `school_id`) are identifier (ID) features. Although stored as numerical values, they represent unique identifiers rather than continuous numerical measurements and are typically removed or treated separately during preprocessing.

# %% [markdown]
# ## How many null values does each feature have? what's your plan for each?

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# order_id                     0
# assignment_id                0
# user_id                      0
# assistment_id                0
# problem_id                   0
# original                     0
# correct                      0
# attempt_count                0
# ms_first_response            0
# tutor_mode                   0
# answer_type                  0
# sequence_id                  0
# student_class_id             0
# position                     0
# type                         0
# base_sequence_id             0
# skill_id                 63755
# skill_name               72270
# teacher_id                   0
# school_id                    0
# hint_count                   0
# hint_total                   0
# overlap_time                 0
# template_id                  0
# answer_id               306818
# answer_text              77630
# first_action                 0
# bottom_hint             287003
# opportunity                  0
# opportunity_original     71402
# dtype: int64

# %% [markdown]
# ## Missing Values and Handling Plan
#
# | Feature | Missing Values | Handling Plan |
# |---------|---------------:|---------------|
# | `Unnamed: 0` | 0 | No action required. |
# | `order_id` | 0 | No action required. |
# | `assignment_id` | 0 | No action required. |
# | `user_id` | 0 | No action required. |
# | `assistment_id` | 0 | No action required. |
# | `problem_id` | 0 | No action required. |
# | `original` | 0 | No action required. |
# | `correct` | 0 | Target column; no missing values. |
# | `attempt_count` | 0 | No action required. |
# | `ms_first_response` | 0 | No action required. |
# | `tutor_mode` | 0 | No action required. |
# | `answer_type` | 0 | No action required. |
# | `sequence_id` | 0 | No action required. |
# | `student_class_id` | 0 | No action required. |
# | `position` | 0 | No action required. |
# | `type` | 0 | No action required. |
# | `base_sequence_id` | 0 | No action required. |
# | `skill_id` | 63,755 | Fill missing values using the corresponding `skill_name` (or vice versa) since they represent the same skill. Remove rows only if both are missing. |
# | `skill_name` | 72,270 | Fill missing values using the corresponding `skill_id` through a mapping table. |
# | `teacher_id` | 0 | No action required. |
# | `school_id` | 0 | No action required. |
# | `hint_count` | 0 | No action required. |
# | `hint_total` | 0 | No action required. |
# | `overlap_time` | 0 | No action required. |
# | `template_id` | 0 | No action required. |
# | `answer_id` | 306,818 | Drop this column because it is an identifier and has a large number of missing values. |
# | `answer_text` | 77,630 | Replace missing values with `"Unknown"` (or the mode) if the feature is used; otherwise, remove the column if it is not relevant to the model. |
# | `first_action` | 0 | No action required. |
# | `bottom_hint` | 287,003 | Replace missing values with `0` (indicating no bottom hint was used). |
# | `opportunity` | 0 | No action required. |
# | `opportunity_original` | 71,402 | Fill missing values using `opportunity` where appropriate, since they are closely related. |
#
# ### Summary
# - **Features with missing values:** 6
# - **Features without missing values:** 25
#
# **Planned preprocessing:**
# - Use mapping between `skill_id` and `skill_name` to recover missing skill information.
# - Drop `answer_id` because it is an identifier with many missing values.
# - Impute `answer_text` with `"Unknown"` if retained.
# - Fill `bottom_hint` with `0`.
# - Fill `opportunity_original` from `opportunity` when possible.

# %% [markdown]
# ## Which features are most correlated with your target, and with each other?

# %% [markdown]
# ## Correlation Analysis
#
# Since this project uses an **unsupervised learning (clustering)** approach, there is **no target variable**. Therefore, correlation analysis is used to identify relationships among the input features and detect redundant variables before clustering.
#
# ### Observations
#
# - **`opportunity` and `opportunity_original`** have an **extremely strong positive correlation (0.98)**, indicating that they contain nearly the same information. One of these features can be removed to reduce redundancy.
# - **`ms_first_response` and `overlap_time`** show a **very strong positive correlation (0.94)**, suggesting that students who spend more time responding also tend to have higher overlap time.
# - **`hint_count` and `first_action`** have a **moderately strong positive correlation (0.63)**, indicating that students who request hints tend to have a similar first interaction behavior.
# - **`hint_count` and `bottom_hint`** have a **moderate positive correlation (0.43)**, suggesting that students requesting more hints are also more likely to use bottom hints.
# - Most of the remaining feature pairs have **weak correlations**, indicating that they provide different information and are unlikely to introduce significant redundancy.
#
# ### Feature Selection Decision
#
# To improve clustering performance and reduce multicollinearity, one feature from each highly correlated pair (e.g., `opportunity_original` or `overlap_time`) may be removed before applying the clustering algorithm.

# %%
df.groupby("first_action")["hint_count"].mean()
# Out:
# first_action
# 0    0.274161
# 1    2.942570
# 2    0.000000
# Name: hint_count, dtype: float64

# %%
df["first_action"].value_counts()
# Out:
# first_action
# 0    309271
# 1     31273
# 2      6316
# Name: count, dtype: int64

# %%
df[df["first_action"] == 2][[
    "correct",
    "attempt_count",
    "hint_count",
    "hint_total",
    "answer_type",
    "tutor_mode"
]].describe(include="all")
# Out:
#         correct  attempt_count  hint_count   hint_total answer_type tutor_mode
# count    6316.0    6316.000000      6316.0  6316.000000        6316       6316
# unique      NaN            NaN         NaN          NaN           3          1
# top         NaN            NaN         NaN          NaN     algebra      tutor
# freq        NaN            NaN         NaN          NaN        5979       6316
# mean        0.0       0.008708         0.0     0.131096         NaN        NaN
# std         0.0       0.140422         0.0     0.613319         NaN        NaN
# min         0.0       0.000000         0.0     0.000000         NaN        NaN
# 25%         0.0       0.000000         0.0     0.000000         NaN        NaN
# 50%         0.0       0.000000         0.0     0.000000         NaN        NaN
# 75%         0.0       0.000000         0.0     0.000000         NaN        NaN
# max         0.0       4.000000         0.0     3.000000         NaN        NaN

# %%
df[df["first_action"] == 2].head(20)
# Out:
#       Unnamed: 0  order_id  assignment_id  user_id  assistment_id  problem_id  \
# 3964        3965  21617692         263600       14          36838       57695
# 3966        3967  21617749         263600       14          36822       57647
# 3968        3969  21617825         263600       14          37068       58551
# 3983        3984  35305686         220655    70363          31403       47081
# 3986        3987  35307058         220655    70363          36823       57650
# 4070        4071  30319263         220665    70872          37067       58548
# 4071        4072  30319442         220665    70872          36820       57641
# 4136        4137  20432779         232255    71826          36838       57695
# 4144        4145  20427027         220655    71877          36843       57710
# 4156        4157  35455538         277620    71881          36822       57647
# 4161        4162  35455871         277621    71881          31426       47150
# 4165        4166  35460671         277621    71881          36826       57659
# 4213        4214  36371426         251690    74459          36843       57710
# 4214        4215  36371444         251690    74459          36832       57677
# 4215        4216  36371459         251690    74459          36836       57689
# 4216        4217  36371474         251690    74459          36841       57704
# 4217        4218  36371489         251690    74459          36821       57644
# 4218        4219  36371505         251690    74459          36844       57713
# 4220        4221  36371529         251690    74459          31422       47138
# 4278        4279  22135327         263982    77954          36849       57728
#
#       original  correct  attempt_count  ms_first_response tutor_mode  \
# 3964         1        0              0              59891      tutor
# 3966         1        0              0              82572      tutor
# 3968         1        0              0              27225      tutor
# 3983         1        0              0              55499      tutor
# 3986         1        0              0              35562      tutor
# 4070         1        0              0              13498      tutor
# 4071         1        0              0              32280      tutor
# 4136         1        0              0             250201      tutor
# 4144         1        0              0              75467      tutor
# 4156         1        0              0            1131591      tutor
# 4161         1        0              0              27831      tutor
# 4165         1        0              0              81525      tutor
# 4213         1        0              0               2343      tutor
# 4214         1        0              0               1391      tutor
# 4215         1        0              0               1152      tutor
# 4216         1        0              0               2423      tutor
# 4217         1        0              0               1416      tutor
# 4218         1        0              0               1512      tutor
# 4220         1        0              0               1482      tutor
# 4278         1        0              0             156224      tutor
#
#      answer_type  sequence_id  student_class_id  position            type  \
# 3964     algebra         5916             12495         2  MasterySection
# 3966     algebra         5916             12495         2  MasterySection
# 3968     algebra         5916             12495         2  MasterySection
# 3983     algebra         5898             11816         3  MasterySection
# 3986     algebra         5898             11816         3  MasterySection
# 4070     algebra         5916             11816        13  MasterySection
# 4071     algebra         5916             11816        13  MasterySection
# 4136     algebra         5898             11971         3  MasterySection
# 4144     algebra         5898             11816         3  MasterySection
# 4156     algebra         5916             13241       128  MasterySection
# 4161     algebra         5898             13241       129  MasterySection
# 4165     algebra         5898             13241       129  MasterySection
# 4213     algebra         5898             12214         3  MasterySection
# 4214     algebra         5898             12214         3  MasterySection
# 4215     algebra         5898             12214         3  MasterySection
# 4216     algebra         5898             12214         3  MasterySection
# 4217     algebra         5898             12214         3  MasterySection
# 4218     algebra         5898             12214         3  MasterySection
# 4220     algebra         5898             12214         3  MasterySection
# 4278     algebra         7711             12340        15  MasterySection
#
#       base_sequence_id    skill_id    skill_name  teacher_id  school_id  \
# 3964              5916     2_48_79  Circle Graph       42972          1
# 3966              5916     2_48_79  Circle Graph       42972          1
# 3968              5916  2_37_48_77  Circle Graph       42972          1
# 3983              5898        2_70  Circle Graph       22763         73
# 3986              5898     2_48_79  Circle Graph       22763         73
# 4070              5916     2_37_48  Circle Graph       22763         73
# 4071              5916     2_48_79  Circle Graph       22763         73
# 4136              5898     2_48_79  Circle Graph       22763         73
# 4144              5898     2_48_79  Circle Graph       22763         73
# 4156              5916     2_48_79  Circle Graph       22763         73
# 4161              5898        2_70  Circle Graph       22763         73
# 4165              5898     2_48_79  Circle Graph       22763         73
# 4213              5898     2_48_79  Circle Graph       45225          1
# 4214              5898     2_48_79  Circle Graph       45225          1
# 4215              5898     2_48_79  Circle Graph       45225          1
# 4216              5898     2_48_79  Circle Graph       45225          1
# 4217              5898     2_48_79  Circle Graph       45225          1
# 4218              5898     2_48_79  Circle Graph       45225          1
# 4220              5898        2_70  Circle Graph       45225          1
# 4278              5916     2_48_79  Circle Graph       11804         76
#
#       hint_count  hint_total  overlap_time  template_id  answer_id  \
# 3964           0           0         59891        30397        NaN
# 3966           0           0         82572        30397        NaN
# 3968           0           0         27225        30790        NaN
# 3983           0           0         55499        30038        NaN
# 3986           0           0         35562        30397        NaN
# 4070           0           0         13498        30790        NaN
# 4071           0           0         32280        30397        NaN
# 4136           0           0        250201        30397        NaN
# 4144           0           0         75467        30397        NaN
# 4156           0           0       1131591        30397        NaN
# 4161           0           0         27831        30038        NaN
# 4165           0           0         81525        30397        NaN
# 4213           0           0          2343        30397        NaN
# 4214           0           0          1391        30397        NaN
# 4215           0           0          1152        30397        NaN
# 4216           0           0          2423        30397        NaN
# 4217           0           0          1416        30397        NaN
# 4218           0           0          1512        30397        NaN
# 4220           0           0          1482        30038        NaN
# 4278           0           0        156224        30397        NaN
#
#      answer_text  first_action  bottom_hint  opportunity  opportunity_original
# 3964         NaN             2          NaN            8                   8.0
# 3966         NaN             2          NaN           10                  10.0
# 3968         NaN             2          NaN           12                  12.0
# 3983         NaN             2          NaN            2                   2.0
# 3986         NaN             2          NaN            5                   5.0
# 4070         NaN             2          NaN            1                   1.0
# 4071         NaN             2          NaN            2                   2.0
# 4136         NaN             2          NaN            2                   2.0
# 4144         NaN             2          NaN            2                   2.0
# 4156         NaN             2          NaN            9                   9.0
# 4161         NaN             2          NaN           14                  14.0
# 4165         NaN             2          NaN           18                  18.0
# 4213         NaN             2          NaN            6                   6.0
# 4214         NaN             2          NaN            7                   7.0
# 4215         NaN             2          NaN            8                   8.0
# 4216         NaN             2          NaN            9                   9.0
# 4217         NaN             2          NaN           10                  10.0
# 4218         NaN             2          NaN           11                  11.0
# 4220         NaN             2          NaN           13                  13.0
# 4278         NaN             2          NaN            9                   9.0

# %%
df=df[
    df["first_action"] < 2
    ]

# %%
# Correlation with the target
# Select only numerical features
numeric_df = df.select_dtypes(include="number")

# (Optional) Remove columns that are IDs or not used in clustering
cols_to_drop = [
    "Unnamed: 0",
    "order_id",
    "user_id",
    "assignment_id",
    "assistment_id",
    "problem_id",
    "sequence_id",
    "base_sequence_id",
    "student_class_id",
    "teacher_id",
    "school_id",
    "template_id",
    "answer_id"
]

numeric_df = numeric_df.drop(columns=cols_to_drop, errors="ignore")

# Compute correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(12, 10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0,
    annot=True
)

plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %% [markdown]
# #### Are there outliers? how would you handle them?

# %%
num_cols = [
    "attempt_count",
    "ms_first_response",
    "position",
    "hint_count",
    "hint_total",
    "overlap_time",
    "first_action",
    "bottom_hint",
    "opportunity"
]

plt.figure(figsize=(16, 12))

for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
outlier_summary = []

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = ((df[col] < lower) | (df[col] > upper)).sum()

    outlier_summary.append({
        "Feature": col,
        "Outliers": outliers,
        "Percentage": round(outliers / len(df) * 100, 2)
    })

outlier_df = pd.DataFrame(outlier_summary).sort_values(
    by="Percentage",
    ascending=False
)

outlier_df
# Out:
#              Feature  Outliers  Percentage
# 0      attempt_count     71536       21.01
# 3         hint_count     59854       17.58
# 8        opportunity     39075       11.47
# 5       overlap_time     32681        9.60
# 1  ms_first_response     31638        9.29
# 6       first_action     31273        9.18
# 2           position     14746        4.33
# 4         hint_total         0        0.00
# 7        bottom_hint         0        0.00

# %% [markdown]
# ## Outlier Analysis
#
# The IQR method was used to detect outliers in the numerical features used for clustering.
#
# | Feature | Outlier Percentage |
# |---------|-------------------:|
# | `attempt_count` | 21.01% |
# | `hint_count` | 17.58% |
# | `opportunity` | 11.47% |
# | `overlap_time` | 9.60% |
# | `ms_first_response` | 9.29% |
# | `first_action` | 9.18% |
# | `position` | 4.33% |
# | `hint_total` | 0.00% |
# | `bottom_hint` | 0.00% |
#
# ### Observations
#
# - Several features contain a noticeable number of outliers, particularly `attempt_count`, `hint_count`, and `opportunity`.
# - These values are expected in educational data and often represent meaningful differences in student learning behaviors rather than data entry errors.
# - Features such as `hint_total` and `bottom_hint` contain no detected outliers.
#
# ### Handling Plan
#
# The detected outliers will **not be removed**, as they may represent important learning patterns that are valuable for identifying distinct student groups. Instead, the numerical features will be scaled using an appropriate scaling technique (e.g., **RobustScaler**) to reduce the influence of extreme values while preserving meaningful behavioral differences for clustering.

# %%
# What is your target column and what does it represent?
# Is your target categorical or continuous? is it balanced (Plot the distribution)?
# What types of features do you have (categorical / numerical)? how many of each ?
# How many null values does each feature have? what's your plan forQ each?
# Which features are most correlated with your target, and with each other?
# Are there outliers? how would you handle them?

# %% [markdown]
# # Topic 2 : Behavior-Based Product Group Recommendation Using Customer Clustering

# %% [markdown]
# ## Problem Statement
#
# E-commerce platforms collect vast amounts of customer interaction data, such as product views, cart additions, and purchases. However, many recommendation systems focus on suggesting individual products rather than groups of complementary products that better match customers' shopping behaviors. This can reduce recommendation relevance and limit cross-selling opportunities. This project aims to analyze customer behavior using machine learning to identify similar shopping patterns and recommend personalized groups of products, improving the shopping experience and recommendation effectiveness.

# %% [markdown]
# ## Data Info
# Data Source : https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store?select=2019-Nov.csv

# %% [markdown]
# # Data Dictionary
#
# | Feature | Data Type | Description |
# |---------|-----------|-------------|
# | `event_time` | DateTime | The date and time when the customer interaction occurred (UTC). |
# | `event_type` | Categorical | Type of customer interaction with the product (`view`, `cart`, `remove_from_cart`, `purchase`). |
# | `product_id` | Integer | Unique identifier of the product. |
# | `category_id` | Integer | Unique identifier of the product category. |
# | `category_code` | Categorical | Hierarchical category name of the product (e.g., `electronics.smartphone`). |
# | `brand` | Categorical | Brand name of the product. Some values may be missing. |
# | `price` | Float | Price of the product. |
# | `user_id` | Integer | Unique identifier of the customer. |
# | `user_session` | Categorical | Unique identifier of the customer's browsing session. |

# %% [markdown]
# ## What is your target column and what does it represent?
# **Target Column:** None
#
# **Representation:** This project uses an **unsupervised learning (clustering)** approach, so there is no target column. Instead, the model groups customers based on their shopping behaviors, such as product views, cart additions, purchases, product categories, brands, and spending patterns. The resulting clusters represent different customer segments that are used to recommend personalized groups of products.

# %% [markdown]
# ## Basic EDA

# %%
df2 = pd.read_csv('data/2019-Nov.csv')
df2.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
#
#                category_code   brand   price    user_id  \
# 0     electronics.smartphone  xiaomi  489.07  520088904
# 1  appliances.sewing_machine  janome  293.65  530496790
# 2                        NaN   creed   28.31  561587266
# 3  appliances.kitchen.washer      lg  712.87  518085591
# 4     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# 4  313628f1-68b8-460d-84f6-cec7a8796ef2

# %%
pd.set_option('display.max_rows', None)
df2['category_code'].value_counts()
# Out:
# category_code
# electronics.smartphone                    16375000
# electronics.video.tv                       2208046
# computers.notebook                         2180554
# electronics.clocks                         2086966
# apparel.shoes                              1886890
# electronics.audio.headphone                1816877
# appliances.environment.vacuum              1528058
# appliances.kitchen.refrigerators           1427162
# appliances.kitchen.washer                  1403866
# computers.desktop                           690502
# furniture.living_room.cabinet               551642
# furniture.bedroom.bed                       532673
# electronics.tablet                          492497
# apparel.shoes.keds                          485802
# auto.accessories.player                     473098
# furniture.living_room.sofa                  425511
# construction.tools.drill                    397860
# appliances.kitchen.oven                     379338
# kids.carriage                               347476
# electronics.telephone                       346800
# appliances.kitchen.blender                  335190
# electronics.audio.subwoofer                 319138
# accessories.bag                             314655
# appliances.kitchen.microwave                306270
# auto.accessories.alarm                      298615
# appliances.iron                             297532
# appliances.environment.air_heater           285987
# appliances.sewing_machine                   280603
# appliances.kitchen.kettle                   279916
# auto.accessories.videoregister              279359
# appliances.kitchen.meat_grinder             256351
# apparel.costume                             245291
# computers.peripherals.printer               221728
# computers.peripherals.monitor               211342
# appliances.environment.water_heater         209371
# kids.toys                                   205974
# construction.tools.generator                204866
# appliances.kitchen.hood                     199057
# furniture.kitchen.table                     198092
# construction.tools.saw                      194878
# furniture.kitchen.chair                     188721
# appliances.kitchen.hob                      186212
# appliances.kitchen.dishwasher               160932
# computers.components.videocards             153514
# construction.tools.welding                  148510
# appliances.kitchen.mixer                    147865
# electronics.audio.acoustic                  142022
# appliances.kitchen.coffee_machine           131557
# appliances.kitchen.grill                    121409
# computers.peripherals.mouse                 115790
# computers.components.hdd                    114907
# sport.bicycle                               108800
# appliances.environment.air_conditioner      101532
# sport.trainer                                96794
# apparel.dress                                96552
# appliances.personal.scales                   94996
# appliances.personal.hair_cutter              90115
# auto.accessories.compressor                  89041
# kids.dolls                                   88366
# furniture.living_room.chair                  88328
# computers.peripherals.keyboard               88325
# computers.components.cpu                     84293
# computers.components.memory                  80095
# computers.components.motherboard             76260
# appliances.kitchen.juicer                    75128
# computers.components.cooler                  73178
# kids.skates                                  72522
# accessories.wallet                           70394
# electronics.camera.video                     65828
# appliances.ironing_board                     63821
# electronics.audio.music_tools.piano          63339
# kids.swing                                   59468
# apparel.jeans                                52966
# apparel.shirt                                51095
# auto.accessories.radar                       49902
# computers.ebooks                             48065
# apparel.underwear                            47712
# construction.components.faucet               47629
# electronics.audio.microphone                 46749
# appliances.personal.massager                 44281
# construction.tools.pump                      43569
# appliances.kitchen.toster                    41192
# computers.components.power_supply            35514
# kids.fmcg.diapers                            32578
# apparel.jumper                               31675
# construction.tools.light                     30784
# furniture.bathroom.toilet                    29237
# furniture.bedroom.pillow                     29234
# furniture.bedroom.blanket                    29140
# apparel.trousers                             25309
# furniture.bathroom.bath                      23163
# electronics.video.projector                  22940
# medicine.tools.tonometer                     22382
# apparel.tshirt                               21556
# construction.tools.painting                  20349
# electronics.camera.photo                     19884
# appliances.kitchen.steam_cooker              19641
# appliances.kitchen.coffee_grinder            18906
# sport.snowboard                              17936
# sport.ski                                    16723
# furniture.universal.light                    16088
# apparel.shoes.sandals                        15343
# auto.accessories.parktronic                  14681
# stationery.cartrige                          12778
# apparel.shoes.moccasins                      12525
# country_yard.cultivator                       9737
# apparel.skirt                                 8837
# sport.tennis                                  7741
# computers.peripherals.camera                  7291
# country_yard.lawn_mower                       6391
# auto.accessories.winch                        5952
# apparel.shoes.slipons                         5613
# accessories.umbrella                          4989
# apparel.belt                                  4698
# apparel.shoes.ballet_shoes                    4379
# apparel.glove                                 3824
# apparel.scarf                                 3618
# apparel.sock                                  3575
# construction.tools.soldering                  3526
# auto.accessories.anti_freeze                  3511
# appliances.environment.fan                    3429
# apparel.shoes.step_ins                        1776
# country_yard.furniture.hammok                 1589
# apparel.shoes.espadrilles                     1412
# apparel.shorts                                 652
# construction.tools.screw                       184
# appliances.kitchen.fryer                       108
# country_yard.furniture.bench                     2
# apparel.jacket                                   1
# Name: count, dtype: int64

# %%
df2.shape
# Out:
# (67501979, 9)

# %% [markdown]
# ## Is your target categorical or continuous? Is it balanced?
#
# **Target Type:** None
#
# **Balanced:** Not applicable.
#
# This project uses an **unsupervised learning (clustering)** approach, which does not require a target variable. Therefore, there is no target to classify as categorical or continuous, and target class balance is not applicable. Instead, the analysis focuses on the distribution of the input features (e.g., `event_type`, `price`, and customer behavior metrics) that are used to group similar customers.

# %% [markdown]
# ## What types of features do you have (categorical / numerical)? how many of each ?

# %% [markdown]
# ### Feature Types
#
# The dataset contains **9 features**, which can be categorized as follows:
#
# ### Categorical Features (4)
#
# - `event_type`
# - `category_code`
# - `brand`
# - `user_session`
#
# ### Numerical Features (5)
#
# - `event_time` *(DateTime feature)*
# - `product_id`
# - `category_id`
# - `price`
# - `user_id`
#
# > **Note:** `event_time` is stored as a **DateTime** feature and will be converted into useful time-based attributes (e.g., hour, day, weekday, or month) during feature engineering. Additionally, `product_id`, `category_id`, and `user_id` are identifier (ID) features and will be used for aggregation rather than as continuous numerical variables.

# %%
df2.dtypes
# Out:
# event_time           str
# event_type           str
# product_id         int64
# category_id        int64
# category_code        str
# brand                str
# price            float64
# user_id            int64
# user_session         str
# dtype: object

# %% [markdown]
# ## How many null values does each feature have? what's your plan for each?

# %% [markdown]
# ### Missing Values and Handling Plan
#
# | Feature | Missing Values | Handling Plan |
# |---------|---------------:|---------------|
# | `event_time` | 0 | No action required. |
# | `event_type` | 0 | No action required. |
# | `product_id` | 0 | No action required. |
# | `category_id` | 0 | No action required. |
# | `category_code` | 21,898,171 | Fill missing values using a mapping from `category_id` to `category_code`. If no mapping exists, replace with `"Unknown"` or remove the records if necessary. |
# | `brand` | 9,224,078 | Replace missing values with `"Unknown"` since many products do not have a recorded brand. |
# | `price` | 0 | No action required. |
# | `user_id` | 0 | No action required. |
# | `user_session` | 10 | Remove the 10 records with missing session IDs, as they represent a negligible portion of the dataset. |
#
# ### Summary
#
# - **Features with missing values:** 3
# - **Features without missing values:** 6
#
# ### Preprocessing Plan
#
# - Recover missing `category_code` values using the corresponding `category_id` where possible.
# - Replace missing `brand` values with `"Unknown"` because many products are unbranded or their brand is unavailable.
# - Remove the 10 rows with missing `user_session` values due to their negligible impact on the dataset.

# %%
df2.isnull().sum()
# Out:
# event_time              0
# event_type              0
# product_id              0
# category_id             0
# category_code    21898171
# brand             9224078
# price                   0
# user_id                 0
# user_session           10
# dtype: int64

# %%
mapping = (
    df2[['category_id', 'category_code']]
    .dropna()
    .drop_duplicates()
)

# %%
df2.groupby('category_id')['category_code'].nunique().sort_values(ascending=False).head()
# Out:
# category_id
# 2187707789055361298    1
# 2053013552226107603    1
# 2186437842832458550    1
# 2053013552293216471    1
# 2053013552326770905    1
# Name: category_code, dtype: int64

# %% [markdown]
# ## Which features are most correlated with your target, and with each other?

# %% [markdown]
# ## Correlation Analysis
#
# Since this project uses an **unsupervised learning (clustering)** approach, there is **no target variable**. Therefore, the analysis focuses on identifying relationships among the customer behavior features.
#
# ### Observations
#
# - **`total_events`** and **`total_views`** have an almost perfect positive correlation (**r = 1.00**), indicating that most customer interactions are product views. These features provide nearly identical information, so one of them may be removed to reduce redundancy.
#
# - **`unique_products`** has a very strong positive correlation with **`unique_brands`** (**r = 0.89**) and **`unique_categories`** (**r = 0.81**). Customers who interact with more products also tend to interact with more brands and product categories.
#
# - **`unique_categories`** and **`unique_brands`** are also highly correlated (**r = 0.89**), suggesting that customers exploring more categories typically interact with more brands.
#
# - **`total_purchases`** and **`total_spending`** show a strong positive correlation (**r = 0.76**), indicating that customers making more purchases generally spend more money.
#
# - **`total_carts`** and **`total_purchases`** have a moderately strong positive correlation (**r = 0.67**), suggesting that customers who add more items to their cart are more likely to complete purchases.
#
# - The conversion rate features (`view_to_cart_rate`, `view_to_purchase_rate`, and `cart_to_purchase_rate`) have relatively weak to moderate correlations with the remaining features, indicating that they provide additional behavioral information rather than duplicating existing features.
#
# ### Feature Selection Decision
#
# To reduce redundancy before clustering, highly correlated features should be reviewed. In particular:
#
# - Keep either **`total_events`** or **`total_views`**, but not both.
# - Consider removing one of **`unique_products`**, **`unique_categories`**, or **`unique_brands`**, since they capture very similar customer behavior.
# - Retain the remaining features, as they provide complementary information about customer purchasing behavior and are expected to improve customer segmentation.

# %%
# from scipy.stats import f_oneway

# groups = [
#     group["price"].values
#     for _, group in df2.groupby("event_type")
# ]

# f_stat, p_value = f_oneway(*groups)

# print(f"F-statistic: {f_stat:.3f}")
# print(f"p-value: {p_value:.5f}")

# %%
df = df2.copy()

df["is_view"] = (df["event_type"] == "view").astype(int)
df["is_cart"] = (df["event_type"] == "cart").astype(int)
df["is_purchase"] = (df["event_type"] == "purchase").astype(int)


df["purchase_value"] = np.where(
    df["event_type"] == "purchase",
    df["price"],
    0
)


customer_features = (
    df.groupby("user_id")
      .agg(
          total_events=("event_type", "count"),
          total_views=("is_view", "sum"),
          total_carts=("is_cart", "sum"),
          total_purchases=("is_purchase", "sum"),
          total_spending=("purchase_value", "sum"),
          avg_interacted_price=("price", "mean"),
          unique_products=("product_id", "nunique"),
          unique_categories=("category_id", "nunique"),
          unique_brands=("brand", "nunique"),
          number_of_sessions=("user_session", "nunique"),
          first_event_time=("event_time", "min"),
          last_event_time=("event_time", "max")
      )
      .reset_index()
)

customer_features.head()
# Out:
#     user_id  total_events  total_views  total_carts  total_purchases  \
# 0  10300217             1            1            0                0
# 1  29515875            11           11            0                0
# 2  31198833            20           20            0                0
# 3  34916060             1            1            0                0
# 4  41798457             1            1            0                0
#
#    total_spending  avg_interacted_price  unique_products  unique_categories  \
# 0             0.0             40.540000                1                  1
# 1             0.0            275.157273                5                  2
# 2             0.0            321.309000               18                  3
# 3             0.0            295.940000                1                  1
# 4             0.0            945.970000                1                  1
#
#    unique_brands  number_of_sessions         first_event_time  \
# 0              1                   1  2019-11-06 06:51:52 UTC
# 1              4                   7  2019-11-10 02:08:39 UTC
# 2              5                   4  2019-11-08 02:09:45 UTC
# 3              1                   1  2019-11-24 07:43:33 UTC
# 4              1                   1  2019-11-26 08:33:16 UTC
#
#            last_event_time
# 0  2019-11-06 06:51:52 UTC
# 1  2019-11-20 15:59:41 UTC
# 2  2019-11-19 01:37:28 UTC
# 3  2019-11-24 07:43:33 UTC
# 4  2019-11-26 08:33:16 UTC

# %%
avg_purchase_price = (
    df[df["event_type"] == "purchase"]
    .groupby("user_id")["price"]
    .mean()
    .rename("avg_purchase_price")
)

customer_features = customer_features.merge(
    avg_purchase_price,
    on="user_id",
    how="left"
)

# %%
customer_features["avg_purchase_price"] = (
    customer_features["avg_purchase_price"].fillna(0)
)

# %%
customer_features["view_to_cart_rate"] = np.where(
    customer_features["total_views"] > 0,
    customer_features["total_carts"] /
    customer_features["total_views"],
    0
)

customer_features["view_to_purchase_rate"] = np.where(
    customer_features["total_views"] > 0,
    customer_features["total_purchases"] /
    customer_features["total_views"],
    0
)

customer_features["cart_to_purchase_rate"] = np.where(
    customer_features["total_carts"] > 0,
    customer_features["total_purchases"] /
    customer_features["total_carts"],
    0
)

# %%
customer_features["first_event_time"] = pd.to_datetime(
    customer_features["first_event_time"],
    errors="coerce",
    utc=True
)

customer_features["last_event_time"] = pd.to_datetime(
    customer_features["last_event_time"],
    errors="coerce",
    utc=True
)

customer_features["activity_days"] = (
    customer_features["last_event_time"]
    - customer_features["first_event_time"]
).dt.total_seconds() / 86400

# %%
customer_features.columns
# Out:
# Index(['user_id', 'total_events', 'total_views', 'total_carts',
#        'total_purchases', 'total_spending', 'avg_interacted_price',
#        'unique_products', 'unique_categories', 'unique_brands',
#        'number_of_sessions', 'first_event_time', 'last_event_time',
#        'avg_purchase_price', 'view_to_cart_rate', 'view_to_purchase_rate',
#        'cart_to_purchase_rate', 'activity_days'],
#       dtype='str')

# %%
clustering_features = [
    "total_events",
    "total_views",
    "total_carts",
    "total_purchases",
    "total_spending",
    "avg_interacted_price",
    "avg_purchase_price",
    "unique_products",
    "unique_categories",
    "unique_brands",
    "number_of_sessions",
    "view_to_cart_rate",
    "view_to_purchase_rate",
    "cart_to_purchase_rate",
    "activity_days"
]

X_cluster = customer_features[clustering_features]

# %%
corr = X_cluster.corr()

plt.figure(figsize=(14,12))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Matrix of Customer Features")
plt.show()

# %%
category_levels = df2['category_code'].str.split('.', expand=True)

df2['category_level1'] = category_levels[0]
df2['category_level2'] = category_levels[1]
df2['category_level3'] = category_levels[2]

# %%
df2['category_level3'] = df2['category_level3'].fillna('None')

# %%
df2['brand'] = df2['brand'].fillna("Unknown")

# %%
df2['event_time'] = pd.to_datetime(df['event_time'])

# %% [markdown]
# ## Are there outliers? how would you handle them?

# %% [markdown]
# ## Outlier Analysis
#
# Outliers were detected using the **Interquartile Range (IQR)** method and visualized using boxplots.
#
# | Feature | Outlier Percentage |
# |---------|-------------------:|
# | `total_carts` | 22.36% |
# | `view_to_cart_rate` | 22.35% |
# | `total_spending` | 11.95% |
# | `avg_purchase_price` | 11.95% |
# | `total_purchases` | 11.95% |
# | `view_to_purchase_rate` | 11.94% |
# | `unique_brands` | 11.75% |
# | `total_events` | 11.51% |
# | `total_views` | 11.30% |
# | `unique_products` | 10.86% |
# | `cart_to_purchase_rate` | 10.82% |
# | `unique_categories` | 9.86% |
# | `number_of_sessions` | 9.61% |
# | `avg_interacted_price` | 7.57% |
# | `activity_days` | 3.70% |
#
# ### Observations
#
# - Most numerical features contain outliers, particularly **`total_carts`** and **`view_to_cart_rate`**, where approximately **22%** of customers were identified as outliers.
# - Features related to customer purchasing behavior (`total_spending`, `total_purchases`, and `avg_purchase_price`) also contain a considerable number of extreme values.
# - The boxplots show that most customers have relatively low activity, while a smaller group of customers exhibits significantly higher levels of interaction and spending.
# - `activity_days` contains the fewest outliers (3.70%), indicating that customer activity duration is more consistently distributed than the other behavioral features.
#
# ### Handling Plan
#
# The detected outliers will **not be removed**, as they represent genuine customer shopping behaviors rather than data entry errors. High-spending customers, frequent purchasers, and highly active users are valuable customer segments that the clustering algorithm should identify.
#
# Instead, the numerical features will be scaled using **RobustScaler**, which reduces the influence of extreme values while preserving meaningful behavioral differences among customers. This approach allows the clustering model to identify distinct customer segments without losing important information.

# %%
num_cols = [
    "total_events",
    "total_views",
    "total_carts",
    "total_purchases",
    "total_spending",
    "avg_interacted_price",
    "avg_purchase_price",
    "unique_products",
    "unique_categories",
    "unique_brands",
    "number_of_sessions",
    "view_to_cart_rate",
    "view_to_purchase_rate",
    "cart_to_purchase_rate",
    "activity_days"
]

plt.figure(figsize=(20, 18))

for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(y=customer_features[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
outlier_summary = []

for col in num_cols:

    Q1 = customer_features[col].quantile(0.25)
    Q3 = customer_features[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = (
        (customer_features[col] < lower) |
        (customer_features[col] > upper)
    ).sum()

    outlier_summary.append({
        "Feature": col,
        "Outliers": outliers,
        "Percentage": round(outliers / len(customer_features) * 100, 2)
    })

outlier_df = (
    pd.DataFrame(outlier_summary)
      .sort_values("Percentage", ascending=False)
)

outlier_df
# Out:
#                   Feature  Outliers  Percentage
# 2             total_carts    826323       22.36
# 11      view_to_cart_rate    825970       22.35
# 4          total_spending    441638       11.95
# 6      avg_purchase_price    441638       11.95
# 3         total_purchases    441638       11.95
# 12  view_to_purchase_rate    441318       11.94
# 9           unique_brands    434379       11.75
# 0            total_events    425280       11.51
# 1             total_views    417732       11.30
# 7         unique_products    401389       10.86
# 13  cart_to_purchase_rate    400047       10.82
# 8       unique_categories    364357        9.86
# 10     number_of_sessions    355074        9.61
# 5    avg_interacted_price    279648        7.57
# 14          activity_days    136929        3.70

# %%
# df2['Brand_Popularity']=
# df2['Total views per user'] = 
# df2['Total carts per user'] = 
# df2['Total purchases per user'] = 
# df2['Average purchases price'] = 
# df2['Brand Loyalty'] = 
# df2['Favorite Category'] =

# %%
# Possible Feature engineering
# User Activity Level
# Repeat Product Purchase
# Price Category

# User Activity Level
# Product Popularity
# Conversion Rate
# User Purchase Count
# Brand Frequency

# %%
# Is your target categorical or continuous? is it balanced (Plot the distribution)?
# What types of features do you have (categorical / numerical)? how many of each ?
# How many null values does each feature have? what's your plan for each?
# Which features are most correlated with your target, and with each other?
# Are there outliers? how would you handle them?

# %% [markdown]
# # Topic 3 : Predicting Anxiety Levels Using Demographic, Lifestyle, and Psychological Factors

# %% [markdown]
# ## Problem Statement
#
# Anxiety is one of the most common mental health conditions and can significantly impact an individual's well-being, productivity, and quality of life. Early identification of anxiety levels can support timely intervention and personalized mental health care. This project aims to develop a machine learning model that predicts an individual's anxiety level based on demographic characteristics, lifestyle habits, physiological measurements, and psychological factors. By analyzing these variables, the model can assist researchers and healthcare professionals in identifying individuals at higher risk of anxiety and supporting data-driven mental health assessments.

# %% [markdown]
# ## Data Info
# Data Source : https://www.kaggle.com/datasets/natezhang123/social-anxiety-dataset?select=enhanced_anxiety_dataset.csv

# %% [markdown]
# # Data Dictionary – Social Anxiety & Stress Level Dataset
#
# | Feature | Data Type | Description |
# |---------|-----------|-------------|
# | **Age** | Integer | Age of the individual in years. |
# | **Gender** | Categorical | Gender of the participant (e.g., Male, Female, Other). |
# | **Occupation** | Categorical | Employment or educational status of the individual. |
# | **Sleep Hours** | Float | Average number of hours slept per night. |
# | **Physical Activity (hrs/week)** | Float | Average hours of physical exercise per week. |
# | **Caffeine Intake (cups/day)** | Integer | Average number of caffeinated drinks consumed per day. |
# | **Alcohol Consumption** | Categorical | Frequency or level of alcohol consumption. |
# | **Smoking** | Categorical | Indicates whether the individual smokes. |
# | **Family History of Anxiety** | Categorical | Whether a close family member has a history of anxiety disorders. |
# | **Stress Level (1–10)** | Integer | **Target variable.** Self-reported stress level, where higher values indicate greater stress. |
# | **Heart Rate (bpm)** | Integer | Average resting heart rate measured in beats per minute. |
# | **Breathing Rate (breaths/min)** | Integer | Average breathing rate per minute. |
# | **Sweating Level (1–5)** | Integer | Self-reported sweating intensity associated with stress or anxiety. |
# | **Dizziness** | Categorical | Indicates whether the individual experiences dizziness. |
# | **Medication** | Categorical | Whether the individual is currently taking medication for anxiety or related conditions. |
# | **Therapy Sessions (per month)** | Integer | Number of therapy or counseling sessions attended each month. |
# | **Recent Major Life Event** | Categorical | Indicates whether the individual has experienced a significant life event recently. |
# | **Diet Quality (1–10)** | Integer | Self-reported quality of daily diet, where higher values indicate healthier eating habits. |
# | **Anxiety Level (1–10)** | Integer | Original target variable measuring social anxiety severity. In this project, it is used as an input feature to predict stress level. |

# %%
df3 = pd.read_csv('./data/enhanced_anxiety_dataset.csv')
df3.head()
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 0                        No                   10               114
# 1                       Yes                    1                62
# 2                       Yes                    1                91
# 3                        No                    4                86
# 4                        No                    1                98
#
#    Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness Medication  \
# 0                            14                     4        No        Yes
# 1                            23                     2       Yes         No
# 2                            28                     3        No         No
# 3                            17                     3        No         No
# 4                            19                     4       Yes        Yes
#
#    Therapy Sessions (per month) Recent Major Life Event  Diet Quality (1-10)  \
# 0                             3                     Yes                    7
# 1                             2                      No                    8
# 2                             1                     Yes                    1
# 3                             0                      No                    1
# 4                             1                      No                    3
#
#    Anxiety Level (1-10)
# 0                   5.0
# 1                   3.0
# 2                   1.0
# 3                   2.0
# 4                   1.0

# %%
df3.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Sleep Hours',
#        'Physical Activity (hrs/week)', 'Caffeine Intake (mg/day)',
#        'Alcohol Consumption (drinks/week)', 'Smoking',
#        'Family History of Anxiety', 'Stress Level (1-10)', 'Heart Rate (bpm)',
#        'Breathing Rate (breaths/min)', 'Sweating Level (1-5)', 'Dizziness',
#        'Medication', 'Therapy Sessions (per month)', 'Recent Major Life Event',
#        'Diet Quality (1-10)', 'Anxiety Level (1-10)'],
#       dtype='str')

# %% [markdown]
# ## What is your target column and what does it represent?**
#
# Target Column: Anxiety Level (1–10)
#
# The target column represents an individual's self-reported anxiety level on a scale from 1 (Very Low Anxiety) to 10 (Very High Anxiety). It serves as the variable that the machine learning model aims to predict using demographic, lifestyle, physiological, and mental health-related features. Because the target is a numerical value, this is a regression problem.

# %% [markdown]
# ## Is your target categorical or continuous? is it balanced (Plot the distribution)?
# The target column is Anxiety Level (1–10), which is a continuous numerical variable because it represents an anxiety score on a scale from 1 to 10. Therefore, the project is a regression task, where the goal is to predict a numeric value rather than assign a class label.
#
# The target variable is not perfectly balanced. Most observations are concentrated in the low to moderate anxiety levels (approximately 2–5), while relatively few samples have high anxiety levels (7–10). This indicates a right-skewed distribution, where higher anxiety scores are underrepresented. Although class balance is not a primary concern in regression problems, this uneven distribution should be considered when evaluating the model, as it may predict moderate anxiety levels more accurately than very high anxiety levels.

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df3,
    x="Anxiety Level (1-10)",   # Replace with your exact column name
    bins=10,
    kde=True,
    color="steelblue"
)

plt.title("Distribution of Anxiety Level")
plt.xlabel("Anxiety Level")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## What types of features do you have (categorical / numerical)? How many of each?
#
# The dataset contains both **numerical** and **categorical** input features.
#
# - **Numerical features (10):**
#   - Age
#   - Sleep Hours
#   - Physical Activity (hrs/week)
#   - Caffeine Intake (cups/day)
#   - Stress Level (1–10)
#   - Heart Rate (bpm)
#   - Breathing Rate (breaths/min)
#   - Sweating Level (1–5)
#   - Therapy Sessions (per month)
#   - Diet Quality (1–10)
#
# - **Categorical features (8):**
#   - Gender
#   - Occupation
#   - Alcohol Consumption
#   - Smoking
#   - Family History of Anxiety
#   - Dizziness
#   - Medication
#   - Recent Major Life Event
#
# Since the dataset contains both numerical and categorical features, different preprocessing techniques will be applied before model training. Numerical features will be scaled using an appropriate scaling method (e.g., **StandardScaler**), while categorical features will be converted into numerical representations using **One-Hot Encoding** or another suitable encoding technique.

# %%
df3.dtypes
# Out:
# Age                                    int64
# Gender                                   str
# Occupation                               str
# Sleep Hours                          float64
# Physical Activity (hrs/week)         float64
# Caffeine Intake (mg/day)               int64
# Alcohol Consumption (drinks/week)      int64
# Smoking                                  str
# Family History of Anxiety                str
# Stress Level (1-10)                    int64
# Heart Rate (bpm)                       int64
# Breathing Rate (breaths/min)           int64
# Sweating Level (1-5)                   int64
# Dizziness                                str
# Medication                               str
# Therapy Sessions (per month)           int64
# Recent Major Life Event                  str
# Diet Quality (1-10)                    int64
# Anxiety Level (1-10)                 float64
# dtype: object

# %% [markdown]
# ## How many null values does each feature have? What's your plan for each?
#
# All features in the dataset contain **0 missing values**, indicating that the dataset is complete and does not require any missing value imputation.
#
# | Feature | Missing Values | Handling Plan |
# |---------|---------------:|---------------|
# | Age | 0 | No action required. |
# | Gender | 0 | No action required. |
# | Occupation | 0 | No action required. |
# | Sleep Hours | 0 | No action required. |
# | Physical Activity (hrs/week) | 0 | No action required. |
# | Caffeine Intake (mg/day) | 0 | No action required. |
# | Alcohol Consumption (drinks/week) | 0 | No action required. |
# | Smoking | 0 | No action required. |
# | Family History of Anxiety | 0 | No action required. |
# | Stress Level (1–10) | 0 | No action required. |
# | Heart Rate (bpm) | 0 | No action required. |
# | Breathing Rate (breaths/min) | 0 | No action required. |
# | Sweating Level (1–5) | 0 | No action required. |
# | Dizziness | 0 | No action required. |
# | Medication | 0 | No action required. |
# | Therapy Sessions (per month) | 0 | No action required. |
# | Recent Major Life Event | 0 | No action required. |
# | Diet Quality (1–10) | 0 | No action required. |
# | Anxiety Level (1–10) *(Target)* | 0 | No action required. |
#
# ### Summary
#
# - **Features with missing values:** **0**
# - **Features without missing values:** **19**
#
# Since there are no missing values, no imputation or row removal is required during data preprocessing. The data can proceed directly to preprocessing steps such as encoding categorical features and scaling numerical features before model training.

# %%
df3.isnull().sum()
# Out:
# Age                                  0
# Gender                               0
# Occupation                           0
# Sleep Hours                          0
# Physical Activity (hrs/week)         0
# Caffeine Intake (mg/day)             0
# Alcohol Consumption (drinks/week)    0
# Smoking                              0
# Family History of Anxiety            0
# Stress Level (1-10)                  0
# Heart Rate (bpm)                     0
# Breathing Rate (breaths/min)         0
# Sweating Level (1-5)                 0
# Dizziness                            0
# Medication                           0
# Therapy Sessions (per month)         0
# Recent Major Life Event              0
# Diet Quality (1-10)                  0
# Anxiety Level (1-10)                 0
# dtype: int64

# %% [markdown]
# ## Which features are most correlated with your target, and with each other?

# %% [markdown]
# ## Correlation Analysis
#
# The correlation matrix was used to examine the relationships between the numerical features and the target variable, **Anxiety Level (1–10)**, as well as the relationships among the numerical features.
#
# ### Observations
#
# - **Stress Level (1–10)** has the **strongest positive correlation** with **Anxiety Level (1–10)** (**r = 0.67**), indicating that higher stress levels are strongly associated with higher anxiety levels.
#
# - **Therapy Sessions (per month)** shows a **moderate positive correlation** with the target (**r = 0.52**), suggesting that individuals with higher anxiety tend to attend therapy more frequently.
#
# - **Sleep Hours** has a **moderate negative correlation** with **Anxiety Level (1–10)** (**r = -0.49**), indicating that individuals who sleep fewer hours generally report higher anxiety levels.
#
# - **Caffeine Intake (mg/day)** has a **weak to moderate positive correlation** with anxiety (**r = 0.35**), suggesting that higher caffeine consumption is associated with slightly higher anxiety levels.
#
# - **Physical Activity (hrs/week)** (**r = -0.24**) and **Diet Quality (1–10)** (**r = -0.22**) have weak negative correlations with anxiety, indicating that healthier lifestyle habits are associated with slightly lower anxiety levels.
#
# - The remaining numerical features, including **Age**, **Alcohol Consumption**, **Heart Rate**, **Breathing Rate**, and **Sweating Level**, show relatively weak correlations with the target (|r| < 0.20).
#
# ### Relationships Between Features
#
# - **Sleep Hours** and **Therapy Sessions (per month)** have a moderate negative correlation (**r = -0.31**), suggesting that individuals who sleep less tend to attend therapy more frequently.
#
# - **Sleep Hours** and **Caffeine Intake (mg/day)** have a weak negative correlation (**r = -0.21**), indicating that lower sleep duration is associated with higher caffeine intake.
#
# - Most feature pairs have **weak correlations**, indicating **low multicollinearity** among the numerical predictors.
#
# ### Feature Selection Decision
#
# No pair of numerical features exhibits a very high correlation (e.g., |r| ≥ 0.80). Therefore, no numerical features need to be removed due to multicollinearity, and all numerical variables can be retained for model training.

# %%
# Select numerical columns
num_cols = df3.select_dtypes(include="number")

# Correlation matrix
corr = num_cols.corr()

# Plot heatmap
plt.figure(figsize=(12, 10))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Are there outliers? how would you handle them?

# %% [markdown]
# ## Outlier Analysis
#
# Outliers were detected using the **Interquartile Range (IQR)** method and visualized using boxplots.
#
# | Feature | Outlier Percentage |
# |---------|-------------------:|
# | Anxiety Level (1–10) | 2.93% |
# | Therapy Sessions (per month) | 1.62% |
# | Sleep Hours | 1.00% |
# | Physical Activity (hrs/week) | 0.51% |
# | Remaining Numerical Features | 0.00% |
#
# ### Observations
#
# - Only a small proportion of the dataset contains outliers, with the highest percentage observed in **Anxiety Level (1–10)** (2.93%), followed by **Therapy Sessions (per month)** (1.62%).
# - **Sleep Hours** and **Physical Activity (hrs/week)** contain a few outliers, representing approximately **1.00%** and **0.51%** of the observations, respectively.
# - The remaining numerical features, including **Age**, **Caffeine Intake**, **Alcohol Consumption**, **Stress Level**, **Heart Rate**, **Breathing Rate**, **Sweating Level**, and **Diet Quality**, do not contain any detected outliers according to the IQR method.
# - Overall, the dataset contains very few outliers, indicating that the numerical features are generally well distributed and do not exhibit extreme variability.
#
# ### Handling Plan
#
# The detected outliers will **not be removed**, as they are likely to represent genuine differences among individuals rather than data entry errors. Removing these observations could reduce the model's ability to learn from naturally occurring variations in anxiety levels and related behaviors.
#
# Since the proportion of outliers is very small (less than 3% for every feature), they are unlikely to have a significant impact on model performance. Therefore, the data will be retained, while numerical features will be scaled during preprocessing (e.g., using **StandardScaler**) before training the predictive model.

# %%
# Select numerical features only
# Select numerical columns from df3

import math

num_cols = df3.select_dtypes(include="number").columns

# Create enough subplot rows automatically
n_cols = 3
n_rows = math.ceil(len(num_cols) / n_cols)

plt.figure(figsize=(18, 4 * n_rows))

for i, col in enumerate(num_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.boxplot(y=df3[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
outlier_summary = []

for col in num_cols:

    Q1 = df3[col].quantile(0.25)
    Q3 = df3[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = ((df3[col] < lower) | (df3[col] > upper)).sum()

    outlier_summary.append({
        "Feature": col,
        "Outliers": outliers,
        "Percentage": round(outliers / len(df3) * 100, 2)
    })

outlier_df = (
    pd.DataFrame(outlier_summary)
      .sort_values("Percentage", ascending=False)
)

outlier_df
# Out:
#                               Feature  Outliers  Percentage
# 11               Anxiety Level (1-10)       322        2.93
# 9        Therapy Sessions (per month)       178        1.62
# 1                         Sleep Hours       110        1.00
# 2        Physical Activity (hrs/week)        56        0.51
# 3            Caffeine Intake (mg/day)         0        0.00
# 0                                 Age         0        0.00
# 4   Alcohol Consumption (drinks/week)         0        0.00
# 5                 Stress Level (1-10)         0        0.00
# 7        Breathing Rate (breaths/min)         0        0.00
# 6                    Heart Rate (bpm)         0        0.00
# 8                Sweating Level (1-5)         0        0.00
# 10                Diet Quality (1-10)         0        0.00
