# %% [markdown]
# ## __Data Science: Capstone Part 2: Lightning Talk 2__

# %% [markdown]
# ## Problem Statement
#
# Online learning platforms such as ASSISTments collect detailed information about student performance and learning behaviors. However, students have different learning needs, making it difficult for educators to provide personalized support.
#
# This project aims to identify distinct student learning profiles based on performance, attempts, response time, hint usage, and practice behavior. These profiles will help educators better understand students' learning needs and provide targeted interventions, with the goal of improving student performance by 10%.

# %% [markdown]
# ## Data Info
# Data Source : https://sites.google.com/site/assistmentsdata/home/2009-2010-assistment-data/skill-builder-data-2009-2010

# %% [markdown]
# ## Objectives
# List the key questions guiding your analysis and modeling:
# - What features influence the target variable?
# - Can feature engineering improve model performance?
# - How do different model versions compare?

# %% [markdown]
# ## Data Dictionary
#
# | Feature | Data Type | Description |
# |---------|----------|-------------|
# | **order_id** | Integer | Chronological identifier of the student's interaction. Larger values indicate later interactions. |
# | **assignment_id** | Integer | Unique identifier of the assignment (homework or activity) created by a teacher for a class. Different teachers can assign the same content but have different assignment IDs. |
# | **user_id** | Integer | Unique identifier for each student. |
# | **assistment_id** | Integer | Identifier of the ASSISTment (tutoring activity). One ASSISTment may contain multiple related problems or scaffold questions. |
# | **problem_id** | Integer | Unique identifier for an individual problem. |
# | **original** | Binary (0/1) | Indicates whether the problem is the original question (`1`) or a scaffold/help question (`0`). |
# | **correct** | Binary (0/1) | Indicates whether the student answered correctly on the first attempt (`1`) or answered incorrectly/requested help (`0`). This is commonly used as the target variable. |
# | **attempt_count** | Integer | Number of attempts the student made before completing the problem. |
# | **ms_first_response** | Integer | Time (in milliseconds) between displaying the problem and the student's first response. |
# | **tutor_mode** | Categorical | Learning mode during the interaction. Possible values include `tutor`and `test` |
# | **answer_type** | Categorical | Type of expected answer (e.g., `choose_1`, `algebra`, `fill_in`, `open_response`). |
# | **sequence_id** | Integer | Identifier of the problem set. Multiple assignments can share the same sequence if they use the same problem set. |
# | **student_class_id** | Integer | Identifier of the student's classroom or class section. |
# | **position** | Integer | Position of the assignment on the student's assignment page. |
# | **problem_set_type** | Categorical | Organization of the problem set. Possible values include `Linear`, `Random`, and `Mastery`. |
# | **base_sequence_id** | Integer | Identifier of the original sequence from which the current sequence was copied. If not copied, it is equal to `sequence_id`. |
# | **skill_id** | Integer | Identifier of the mathematical skill associated with the problem. In the Skill Builder dataset, each row contains only one skill. Multi-skill problems are duplicated into multiple rows. |
# | **skill_name** | String | Name of the mathematical skill associated with the problem. |
# | **teacher_id** | Integer | Unique identifier of the teacher who assigned the problem. |
# | **school_id** | Integer | Unique identifier of the school. |
# | **hint_count** | Integer | Number of hints requested by the student while solving the problem. |
# | **hint_total** | Integer | Total number of hints available for the problem. |
# | **overlap_time** | Integer | Time (in milliseconds) representing overlapping student activity while interacting with the problem. |
# | **template_id** | Integer | Identifier of the ASSISTment template. Problems sharing the same template have similar structures but different values. |
# | **answer_id** | Integer | Identifier of the selected answer for multiple-choice questions. |
# | **answer_text** | String | Student's submitted answer for fill-in or text-based questions. |
# | **first_action** | Categorical | Student's first action after viewing the problem, such as `attempt` or `hint`. |
# | **bottom_hint** | Binary (0/1) | Indicates whether the student requested the bottom-out hint (the final hint revealing the solution). |
# | **opportunity** | Integer | Number of previous opportunities the student has had to practice the associated skill. |
# | **opportunity_original** | Integer | Number of previous opportunities the student has had to practice the skill considering only original problems (`original = 1`). |
# | **correct** | Binary (0/1) | Binary target variable indicating whether the student answered the problem correctly on the first attempt. `1` = Correct, `0` = Incorrect or requested help. |
#
# ---
#
# # Feature Categories
#
# | Category | Features |
# |----------|----------|
# | **Student Information** | `user_id`, `student_class_id`, `teacher_id`, `school_id` |
# | **Assignment Information** | `assignment_id`, `sequence_id`, `base_sequence_id`, `position`, `problem_set_type` |
# | **Problem Information** | `assistment_id`, `problem_id`, `template_id`, `original` |
# | **Skill Information** | `skill_id`, `skill_name`, `opportunity`, `opportunity_original` |
# | **Student Behavior** | `attempt_count`, `hint_count`, `hint_total`, `ms_first_response`, `overlap_time`, `first_action`, `bottom_hint` |
# | **Response Information** | `correct`, `answer_type`, `answer_id`, `answer_text` |
#
# ---
#
# # Notes
#
# - **`correct`** is the primary target variable used in most machine learning tasks on this dataset.
# - The **Skill Builder** version stores **one skill per row**. If a problem assesses multiple skills, the interaction is duplicated so that each row corresponds to a single skill.
# - Time-related features (`ms_first_response`, `overlap_time`) are measured in **milliseconds (ms)**.
# - Columns ending with `_id` are identifiers and generally should not be treated as continuous numerical variables. Depending on the modeling approach, they may be removed, encoded, or used for grouping.
# - `opportunity` and `opportunity_original` are important educational features because they measure how many times a student has previously practiced a skill, making them valuable predictors of student mastery.

# %%
# start you EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
# From Scikit-Learn (Best for fitting models and predicting cluster labels)
from sklearn.cluster import AgglomerativeClustering

# From SciPy (Best for creating and plotting dendrograms)
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
pip install hdbscan
# Out:
# Requirement already satisfied: hdbscan in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (0.8.44)
# Requirement already satisfied: numpy<3,>=1.20 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from hdbscan) (2.5.0)
# Requirement already satisfied: scipy>=1.0 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from hdbscan) (1.18.0)
# Requirement already satisfied: scikit-learn>=1.6 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from hdbscan) (1.9.0)
# Requirement already satisfied: joblib>=1.0 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from hdbscan) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from scikit-learn>=1.6->hdbscan) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\elias\GA_DSB\ga_dsb_env\Lib\site-packages (from scikit-learn>=1.6->hdbscan) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df = pd.read_csv('data/skill_builder_data_corrected_collapsed.csv', encoding='latin-1')
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_15312\102637691.py:1: DtypeWarning: Columns (0: skill_id, 1: skill_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/skill_builder_data_corrected_collapsed.csv', encoding='latin-1')

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    Unnamed: 0  order_id  assignment_id  user_id  assistment_id  problem_id  \
# 0           1  33022537         277618    64525          33139       51424
# 1           2  33022709         277618    64525          33150       51435
# 2           3  35450204         220674    70363          33159       51444
# 3           4  35450295         220674    70363          33110       51395
# 4           5  35450311         220674    70363          33196       51481
#
#    original  correct  attempt_count  ms_first_response tutor_mode answer_type  \
# 0         1        1              1              32454      tutor     algebra
# 1         1        1              1               4922      tutor     algebra
# 2         1        0              2              25390      tutor     algebra
# 3         1        1              1               4859      tutor     algebra
# 4         1        0             14              19813      tutor     algebra
#
#    sequence_id  student_class_id  position            type  base_sequence_id  \
# 0         5948             13241       126  MasterySection              5948
# 1         5948             13241       126  MasterySection              5948
# 2         5948             11816        22  MasterySection              5948
# 3         5948             11816        22  MasterySection              5948
# 4         5948             11816        22  MasterySection              5948
#
#   skill_id       skill_name  teacher_id  school_id  hint_count  hint_total  \
# 0     1_13  Box and Whisker       22763         73           0           3
# 1     1_13  Box and Whisker       22763         73           0           3
# 2     1_13  Box and Whisker       22763         73           0           3
# 3     1_13  Box and Whisker       22763         73           0           3
# 4     1_15  Box and Whisker       22763         73           3           4
#
#    overlap_time  template_id  answer_id answer_text  first_action  \
# 0         32454        30799        NaN          26             0
# 1          4922        30799        NaN          55             0
# 2         42000        30799        NaN          88             0
# 3          4859        30059        NaN          41             0
# 4        124564        30060        NaN          65             0
#
#    bottom_hint  opportunity  opportunity_original
# 0          NaN            1                   1.0
# 1          NaN            2                   2.0
# 2          NaN            1                   1.0
# 3          NaN            2                   2.0
# 4          0.0            3                   3.0

# %%
df.shape
# Out:
# (346860, 31)

# %% [markdown]
# #### Is your target categorical or continuous? is it balanced (Plot the distribution)? categorical, Not balance
#
# This project uses an **unsupervised learning (clustering)** approach, so there is no target variable to classify as categorical or continuous. Consequently, target class balance and target distribution are not applicable. Instead, the analysis focuses on the distribution of the input features used to group students into learning profiles.

# %% [markdown]
# #### What types of features do you have (categorical / numerical)? how many of each ?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'assignment_id', 'user_id', 'assistment_id',
#        'problem_id', 'original', 'correct', 'attempt_count',
#        'ms_first_response', 'tutor_mode', 'answer_type', 'sequence_id',
#        'student_class_id', 'position', 'type', 'base_sequence_id', 'skill_id',
#        'skill_name', 'teacher_id', 'school_id', 'hint_count', 'hint_total',
#        'overlap_time', 'template_id', 'answer_id', 'answer_text',
#        'first_action', 'bottom_hint', 'opportunity', 'opportunity_original'],
#       dtype='str')

# %%
df['skill_name'].value_counts()
# Out:
# skill_name
# Equation Solving Two or Fewer Steps         24253
# Conversion of Fraction Decimals Percents    18742
# Addition and Subtraction Integers           12741
# Addition and Subtraction Fractions          11334
# Equation Solving More Than Two Steps         8115
#                                             ...
# Distributive Property                          18
# Finding Slope From Situation                    9
# Recognize Quadratic Pattern                     8
# Reading a Ruler or Scale                        5
# Finding Slope from Ordered Pairs                5
# Name: count, Length: 101, dtype: int64

# %%
df['tutor_mode'].value_counts()
# Out:
# tutor_mode
# tutor    346601
# test        259
# Name: count, dtype: int64

# %%
df['answer_type'].value_counts()
# Out:
# answer_type
# algebra          270780
# choose_1          41181
# fill_in_1         34786
# choose_n            105
# open_response         8
# Name: count, dtype: int64

# %%
df['first_action'].value_counts()
# Out:
# first_action
# 0    309271
# 1     31273
# 2      6316
# Name: count, dtype: int64

# %%
df['bottom_hint'].value_counts()
# Out:
# bottom_hint
# 1.0    42932
# 0.0    16925
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 346860 entries, 0 to 346859
# Data columns (total 31 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            346860 non-null  int64
#  1   order_id              346860 non-null  int64
#  2   assignment_id         346860 non-null  int64
#  3   user_id               346860 non-null  int64
#  4   assistment_id         346860 non-null  int64
#  5   problem_id            346860 non-null  int64
#  6   original              346860 non-null  int64
#  7   correct               346860 non-null  int64
#  8   attempt_count         346860 non-null  int64
#  9   ms_first_response     346860 non-null  int64
#  10  tutor_mode            346860 non-null  str
#  11  answer_type           346860 non-null  str
#  12  sequence_id           346860 non-null  int64
#  13  student_class_id      346860 non-null  int64
#  14  position              346860 non-null  int64
#  15  type                  346860 non-null  str
#  16  base_sequence_id      346860 non-null  int64
#  17  skill_id              283105 non-null  object
#  18  skill_name            274590 non-null  str
#  19  teacher_id            346860 non-null  int64
#  20  school_id             346860 non-null  int64
#  21  hint_count            346860 non-null  int64
#  22  hint_total            346860 non-null  int64
#  23  overlap_time          346860 non-null  int64
#  24  template_id           346860 non-null  int64
#  25  answer_id             40042 non-null   float64
#  26  answer_text           269230 non-null  str
#  27  first_action          346860 non-null  int64
#  28  bottom_hint           59857 non-null   float64
#  29  opportunity           346860 non-null  int64
#  30  opportunity_original  275458 non-null  float64
# dtypes: float64(3), int64(22), object(1), str(5)
# memory usage: 98.3+ MB

# %%
df[df['bottom_hint'].isnull()]
# Out:
#         Unnamed: 0  order_id  assignment_id  user_id  assistment_id  \
# 0                1  33022537         277618    64525          33139
# 1                2  33022709         277618    64525          33150
# 2                3  35450204         220674    70363          33159
# 3                4  35450295         220674    70363          33110
# 5                6  35450555         220674    70363          33172
# ...            ...       ...            ...      ...            ...
# 346854      401751  38214011         291495    96299          57822
# 346855      401752  38214014         291495    96299          57830
# 346856      401753  38214016         291495    96299          57843
# 346857      401754  38214195         291503    96299          34577
# 346858      401755  38214196         291503    96299          34577
#
#         problem_id  original  correct  attempt_count  ms_first_response  \
# 0            51424         1        1              1              32454
# 1            51435         1        1              1               4922
# 2            51444         1        0              2              25390
# 3            51395         1        1              1               4859
# 5            51457         1        1              1              16031
# ...            ...       ...      ...            ...                ...
# 346854      108953         0        1              1               3375
# 346855      108976         0        1              1              38234
# 346856      109015         0        1              1               6500
# 346857       54060         0        1              1              18344
# 346858       54061         0        1              1              12922
#
#        tutor_mode answer_type  sequence_id  student_class_id  position  \
# 0           tutor     algebra         5948             13241       126
# 1           tutor     algebra         5948             13241       126
# 2           tutor     algebra         5948             11816        22
# 3           tutor     algebra         5948             11816        22
# 5           tutor     algebra         5948             11816        22
# ...           ...         ...          ...               ...       ...
# 346854      tutor    choose_1         6009             14415        39
# 346855      tutor    choose_1         6009             14415        39
# 346856      tutor    choose_1         6009             14415        39
# 346857      tutor     algebra         5962             14415        16
# 346858      tutor     algebra         5962             14415        16
#
#                   type  base_sequence_id skill_id       skill_name  \
# 0       MasterySection              5948     1_13  Box and Whisker
# 1       MasterySection              5948     1_13  Box and Whisker
# 2       MasterySection              5948     1_13  Box and Whisker
# 3       MasterySection              5948     1_13  Box and Whisker
# 5       MasterySection              5948     1_15  Box and Whisker
# ...                ...               ...      ...              ...
# 346854  MasterySection              6009      NaN              NaN
# 346855  MasterySection              6009      NaN              NaN
# 346856  MasterySection              6009      NaN              NaN
# 346857  MasterySection              5962      NaN              NaN
# 346858  MasterySection              5962      NaN              NaN
#
#         teacher_id  school_id  hint_count  hint_total  overlap_time  \
# 0            22763         73           0           3         32454
# 1            22763         73           0           3          4922
# 2            22763         73           0           3         42000
# 3            22763         73           0           3          4859
# 5            22763         73           0           4         16031
# ...            ...        ...         ...         ...           ...
# 346854       69274       2770           0           1          3375
# 346855       69274       2770           0           2         38234
# 346856       69274       2770           0           0          6500
# 346857       69274       2770           0           3         18344
# 346858       69274       2770           0           2         12922
#
#         template_id  answer_id answer_text  first_action  bottom_hint  \
# 0             30799        NaN          26             0          NaN
# 1             30799        NaN          55             0          NaN
# 2             30799        NaN          88             0          NaN
# 3             30059        NaN          41             0          NaN
# 5             30060        NaN          12             0          NaN
# ...             ...        ...         ...           ...          ...
# 346854        55691   200237.0         NaN             0          NaN
# 346855        55692   200260.0         NaN             0          NaN
# 346856        55693   200299.0         NaN             0          NaN
# 346857        30677        NaN         0.8             0          NaN
# 346858        30677        NaN          -6             0          NaN
#
#         opportunity  opportunity_original
# 0                 1                   1.0
# 1                 2                   2.0
# 2                 1                   1.0
# 3                 2                   2.0
# 5                 4                   4.0
# ...             ...                   ...
# 346854           53                   NaN
# 346855           54                   NaN
# 346856           55                   NaN
# 346857           56                   NaN
# 346858           57                   NaN
#
# [287003 rows x 31 columns]

# %%
df[(df['bottom_hint'].isnull())&
    (df['hint_count']>=1)
]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, assignment_id, user_id, assistment_id, problem_id, original, correct, attempt_count, ms_first_response, tutor_mode, answer_type, sequence_id, student_class_id, position, type, base_sequence_id, skill_id, skill_name, teacher_id, school_id, hint_count, hint_total, overlap_time, template_id, answer_id, answer_text, first_action, bottom_hint, opportunity, opportunity_original]
# Index: []

# %%
df[
    (df['correct'] == 1) &
    (df['attempt_count'] == 3)
]
# Out:
#         Unnamed: 0  order_id  assignment_id  user_id  assistment_id  \
# 6682          6683  30145384         270288    79018          53495
# 6931          6932  30062521         270288    79033          53491
# 9679          9680  38290132         291366    96262          53495
# 9879          9880  38300582         291366    96275          53491
# 33712        38110  22991076         265503    82341          51815
# ...            ...       ...            ...      ...            ...
# 339055      393952  38277412         290921    96232          57424
# 340978      395875  38215134         291495    96253          57837
# 341392      396289  38164569         291495    96257          57836
# 342988      397885  38225650         291495    96272          57811
# 343004      397901  38225733         291503    96272          34582
#
#         problem_id  original  correct  attempt_count  ms_first_response  \
# 6682         93466         1        1              3              10462
# 6931         93462         1        1              3              24948
# 9679         93466         1        1              3              10462
# 9879         93462         1        1              3              24948
# 33712        91139         1        1              3              49441
# ...            ...       ...      ...            ...                ...
# 339055      107958         0        1              3               4646
# 340978      108997         0        1              3              26206
# 341392      108995         0        1              3               8990
# 342988      108920         0        1              3              30861
# 343004       54082         0        1              3              19051
#
#        tutor_mode answer_type  sequence_id  student_class_id  position  \
# 6682        tutor     algebra         7118             12351       149
# 6931        tutor     algebra         7118             12351       149
# 9679        tutor     algebra         7118             14415       147
# 9879        tutor     algebra         7118             14415       147
# 33712       tutor     algebra         7035             12507         5
# ...           ...         ...          ...               ...       ...
# 339055      tutor    choose_1         5969             14414        71
# 340978      tutor    choose_1         6009             14415        39
# 341392      tutor    choose_1         6009             14415        39
# 342988      tutor    choose_1         6009             14415        39
# 343004      tutor     algebra         5962             14415        16
#
#                   type  base_sequence_id    skill_id    skill_name  \
# 6682    MasterySection              7118  2_37_48_77  Circle Graph
# 6931    MasterySection              7118  2_37_48_77  Circle Graph
# 9679    MasterySection              7118  2_37_48_77  Circle Graph
# 9879    MasterySection              7118  2_37_48_77  Circle Graph
# 33712   MasterySection              7035          13        Median
# ...                ...               ...         ...           ...
# 339055  MasterySection              5969         NaN           NaN
# 340978  MasterySection              6009         NaN           NaN
# 341392  MasterySection              6009         NaN           NaN
# 342988  MasterySection              6009         NaN           NaN
# 343004  MasterySection              5962         NaN           NaN
#
#         teacher_id  school_id  hint_count  hint_total  overlap_time  \
# 6682         42999       2770           0           3         10462
# 6931         42999       2770           0           3         24948
# 9679         69274       2770           0           3         10462
# 9879         69274       2770           0           3         24948
# 33712        43015       2770           0           3         49441
# ...            ...        ...         ...         ...           ...
# 339055       69274       2770           0           0          4646
# 340978       69274       2770           0           0         26206
# 341392       69274       2770           0           0          8990
# 342988       69274       2770           0           0         30861
# 343004       69274       2770           0           3         19051
#
#         template_id  answer_id answer_text  first_action  bottom_hint  \
# 6682          52571        NaN          72             0          NaN
# 6931          52571        NaN          30             0          NaN
# 9679          52571        NaN          72             0          NaN
# 9879          52571        NaN          30             0          NaN
# 33712         50237        NaN          39             0          NaN
# ...             ...        ...         ...           ...          ...
# 339055        55834   198523.0         NaN             0          NaN
# 340978        55693   200281.0         NaN             0          NaN
# 341392        55693   200279.0         NaN             0          NaN
# 342988        55690   200204.0         NaN             0          NaN
# 343004        30677        NaN           4             0          NaN
#
#         opportunity  opportunity_original
# 6682              3                   3.0
# 6931              3                   3.0
# 9679              2                   2.0
# 9879              6                   6.0
# 33712             3                   3.0
# ...             ...                   ...
# 339055          141                   NaN
# 340978           97                   NaN
# 341392           69                   NaN
# 342988           19                   NaN
# 343004           35                   NaN
#
# [119 rows x 31 columns]

# %%
df[(df['hint_total']==0)&
    (df['hint_count']==0)&
    (df['bottom_hint'].isnull())    
]
# Out:
#         Unnamed: 0  order_id  assignment_id  user_id  assistment_id  \
# 162            163  31131882         271985    78073          73222
# 200            201  31036654         271963    78905          73236
# 211            212  30946949         271963    78906          73236
# 280            281  30948060         271963    78912          73236
# 285            286  30948233         271963    78912          73219
# ...            ...       ...            ...      ...            ...
# 346802      401699  38213629         291449    96299          57475
# 346803      401700  38213640         291449    96299          57474
# 346852      401749  38214004         291495    96299          57831
# 346853      401750  38214010         291495    96299          57832
# 346856      401753  38214016         291495    96299          57843
#
#         problem_id  original  correct  attempt_count  ms_first_response  \
# 162         135647         1        1              1               5594
# 200         135661         1        1              1               5900
# 211         135661         1        1              1               4812
# 280         135661         1        0              2              43279
# 285         135644         1        1              1               4178
# ...            ...       ...      ...            ...                ...
# 346802      108183         0        0              2              16630
# 346803      108178         0        1              1               6968
# 346852      108980         0        1              1               4703
# 346853      108982         0        1              2               5969
# 346856      109015         0        1              1               6500
#
#        tutor_mode answer_type  sequence_id  student_class_id  position  \
# 162         tutor     algebra         9879             12887        30
# 200         tutor     algebra         9879             12886        30
# 211         tutor     algebra         9879             12886        30
# 280         tutor     algebra         9879             12886        30
# 285         tutor     algebra         9879             12886        30
# ...           ...         ...          ...               ...       ...
# 346802      tutor     algebra         5969             14415        62
# 346803      tutor     algebra         5969             14415        62
# 346852      tutor    choose_1         6009             14415        39
# 346853      tutor    choose_1         6009             14415        39
# 346856      tutor    choose_1         6009             14415        39
#
#                   type  base_sequence_id skill_id       skill_name  \
# 162     MasterySection              9879        1  Box and Whisker
# 200     MasterySection              9879        1  Box and Whisker
# 211     MasterySection              9879        1  Box and Whisker
# 280     MasterySection              9879        1  Box and Whisker
# 285     MasterySection              9879        1  Box and Whisker
# ...                ...               ...      ...              ...
# 346802  MasterySection              5969      NaN              NaN
# 346803  MasterySection              5969      NaN              NaN
# 346852  MasterySection              6009      NaN              NaN
# 346853  MasterySection              6009      NaN              NaN
# 346856  MasterySection              6009      NaN              NaN
#
#         teacher_id  school_id  hint_count  hint_total  overlap_time  \
# 162          42999       2770           0           0          5594
# 200          42999       2770           0           0          5900
# 211          42999       2770           0           0          4812
# 280          42999       2770           0           0         80440
# 285          42999       2770           0           0          4178
# ...            ...        ...         ...         ...           ...
# 346802       69274       2770           0           0         45496
# 346803       69274       2770           0           0          6968
# 346852       69274       2770           0           0          4703
# 346853       69274       2770           0           0          5969
# 346856       69274       2770           0           0          6500
#
#         template_id  answer_id answer_text  first_action  bottom_hint  \
# 162           63446        NaN          86             0          NaN
# 200           63447        NaN          75             0          NaN
# 211           63447        NaN          75             0          NaN
# 280           63447        NaN          76             0          NaN
# 285           63446        NaN          51             0          NaN
# ...             ...        ...         ...           ...          ...
# 346802        55834        NaN          70             0          NaN
# 346803        55834        NaN          44             0          NaN
# 346852        55692   200264.0         NaN             0          NaN
# 346853        55692   200266.0         NaN             0          NaN
# 346856        55693   200299.0         NaN             0          NaN
#
#         opportunity  opportunity_original
# 162              10                  10.0
# 200               4                   4.0
# 211               5                   5.0
# 280               1                   1.0
# 285               6                   6.0
# ...             ...                   ...
# 346802            1                   NaN
# 346803            2                   NaN
# 346852           51                   NaN
# 346853           52                   NaN
# 346856           55                   NaN
#
# [101551 rows x 31 columns]

# %%
df['bottom_hint'] = df['bottom_hint'].fillna(0)

# %%
df["first_action"].value_counts()
# Out:
# first_action
# 0    309271
# 1     31273
# 2      6316
# Name: count, dtype: int64

# %%
df[df["first_action"] == 2][[
    "correct",
    "attempt_count",
    "hint_count",
    "hint_total",
    "answer_type",
    "tutor_mode"
]].describe(include="all")
# Out:
#         correct  attempt_count  hint_count   hint_total answer_type tutor_mode
# count    6316.0    6316.000000      6316.0  6316.000000        6316       6316
# unique      NaN            NaN         NaN          NaN           3          1
# top         NaN            NaN         NaN          NaN     algebra      tutor
# freq        NaN            NaN         NaN          NaN        5979       6316
# mean        0.0       0.008708         0.0     0.131096         NaN        NaN
# std         0.0       0.140422         0.0     0.613319         NaN        NaN
# min         0.0       0.000000         0.0     0.000000         NaN        NaN
# 25%         0.0       0.000000         0.0     0.000000         NaN        NaN
# 50%         0.0       0.000000         0.0     0.000000         NaN        NaN
# 75%         0.0       0.000000         0.0     0.000000         NaN        NaN
# max         0.0       4.000000         0.0     3.000000         NaN        NaN

# %%
df[df["first_action"] == 2].head(20)
# Out:
#       Unnamed: 0  order_id  assignment_id  user_id  assistment_id  problem_id  \
# 3964        3965  21617692         263600       14          36838       57695
# 3966        3967  21617749         263600       14          36822       57647
# 3968        3969  21617825         263600       14          37068       58551
# 3983        3984  35305686         220655    70363          31403       47081
# 3986        3987  35307058         220655    70363          36823       57650
# 4070        4071  30319263         220665    70872          37067       58548
# 4071        4072  30319442         220665    70872          36820       57641
# 4136        4137  20432779         232255    71826          36838       57695
# 4144        4145  20427027         220655    71877          36843       57710
# 4156        4157  35455538         277620    71881          36822       57647
# 4161        4162  35455871         277621    71881          31426       47150
# 4165        4166  35460671         277621    71881          36826       57659
# 4213        4214  36371426         251690    74459          36843       57710
# 4214        4215  36371444         251690    74459          36832       57677
# 4215        4216  36371459         251690    74459          36836       57689
# 4216        4217  36371474         251690    74459          36841       57704
# 4217        4218  36371489         251690    74459          36821       57644
# 4218        4219  36371505         251690    74459          36844       57713
# 4220        4221  36371529         251690    74459          31422       47138
# 4278        4279  22135327         263982    77954          36849       57728
#
#       original  correct  attempt_count  ms_first_response tutor_mode  \
# 3964         1        0              0              59891      tutor
# 3966         1        0              0              82572      tutor
# 3968         1        0              0              27225      tutor
# 3983         1        0              0              55499      tutor
# 3986         1        0              0              35562      tutor
# 4070         1        0              0              13498      tutor
# 4071         1        0              0              32280      tutor
# 4136         1        0              0             250201      tutor
# 4144         1        0              0              75467      tutor
# 4156         1        0              0            1131591      tutor
# 4161         1        0              0              27831      tutor
# 4165         1        0              0              81525      tutor
# 4213         1        0              0               2343      tutor
# 4214         1        0              0               1391      tutor
# 4215         1        0              0               1152      tutor
# 4216         1        0              0               2423      tutor
# 4217         1        0              0               1416      tutor
# 4218         1        0              0               1512      tutor
# 4220         1        0              0               1482      tutor
# 4278         1        0              0             156224      tutor
#
#      answer_type  sequence_id  student_class_id  position            type  \
# 3964     algebra         5916             12495         2  MasterySection
# 3966     algebra         5916             12495         2  MasterySection
# 3968     algebra         5916             12495         2  MasterySection
# 3983     algebra         5898             11816         3  MasterySection
# 3986     algebra         5898             11816         3  MasterySection
# 4070     algebra         5916             11816        13  MasterySection
# 4071     algebra         5916             11816        13  MasterySection
# 4136     algebra         5898             11971         3  MasterySection
# 4144     algebra         5898             11816         3  MasterySection
# 4156     algebra         5916             13241       128  MasterySection
# 4161     algebra         5898             13241       129  MasterySection
# 4165     algebra         5898             13241       129  MasterySection
# 4213     algebra         5898             12214         3  MasterySection
# 4214     algebra         5898             12214         3  MasterySection
# 4215     algebra         5898             12214         3  MasterySection
# 4216     algebra         5898             12214         3  MasterySection
# 4217     algebra         5898             12214         3  MasterySection
# 4218     algebra         5898             12214         3  MasterySection
# 4220     algebra         5898             12214         3  MasterySection
# 4278     algebra         7711             12340        15  MasterySection
#
#       base_sequence_id    skill_id    skill_name  teacher_id  school_id  \
# 3964              5916     2_48_79  Circle Graph       42972          1
# 3966              5916     2_48_79  Circle Graph       42972          1
# 3968              5916  2_37_48_77  Circle Graph       42972          1
# 3983              5898        2_70  Circle Graph       22763         73
# 3986              5898     2_48_79  Circle Graph       22763         73
# 4070              5916     2_37_48  Circle Graph       22763         73
# 4071              5916     2_48_79  Circle Graph       22763         73
# 4136              5898     2_48_79  Circle Graph       22763         73
# 4144              5898     2_48_79  Circle Graph       22763         73
# 4156              5916     2_48_79  Circle Graph       22763         73
# 4161              5898        2_70  Circle Graph       22763         73
# 4165              5898     2_48_79  Circle Graph       22763         73
# 4213              5898     2_48_79  Circle Graph       45225          1
# 4214              5898     2_48_79  Circle Graph       45225          1
# 4215              5898     2_48_79  Circle Graph       45225          1
# 4216              5898     2_48_79  Circle Graph       45225          1
# 4217              5898     2_48_79  Circle Graph       45225          1
# 4218              5898     2_48_79  Circle Graph       45225          1
# 4220              5898        2_70  Circle Graph       45225          1
# 4278              5916     2_48_79  Circle Graph       11804         76
#
#       hint_count  hint_total  overlap_time  template_id  answer_id  \
# 3964           0           0         59891        30397        NaN
# 3966           0           0         82572        30397        NaN
# 3968           0           0         27225        30790        NaN
# 3983           0           0         55499        30038        NaN
# 3986           0           0         35562        30397        NaN
# 4070           0           0         13498        30790        NaN
# 4071           0           0         32280        30397        NaN
# 4136           0           0        250201        30397        NaN
# 4144           0           0         75467        30397        NaN
# 4156           0           0       1131591        30397        NaN
# 4161           0           0         27831        30038        NaN
# 4165           0           0         81525        30397        NaN
# 4213           0           0          2343        30397        NaN
# 4214           0           0          1391        30397        NaN
# 4215           0           0          1152        30397        NaN
# 4216           0           0          2423        30397        NaN
# 4217           0           0          1416        30397        NaN
# 4218           0           0          1512        30397        NaN
# 4220           0           0          1482        30038        NaN
# 4278           0           0        156224        30397        NaN
#
#      answer_text  first_action  bottom_hint  opportunity  opportunity_original
# 3964         NaN             2          0.0            8                   8.0
# 3966         NaN             2          0.0           10                  10.0
# 3968         NaN             2          0.0           12                  12.0
# 3983         NaN             2          0.0            2                   2.0
# 3986         NaN             2          0.0            5                   5.0
# 4070         NaN             2          0.0            1                   1.0
# 4071         NaN             2          0.0            2                   2.0
# 4136         NaN             2          0.0            2                   2.0
# 4144         NaN             2          0.0            2                   2.0
# 4156         NaN             2          0.0            9                   9.0
# 4161         NaN             2          0.0           14                  14.0
# 4165         NaN             2          0.0           18                  18.0
# 4213         NaN             2          0.0            6                   6.0
# 4214         NaN             2          0.0            7                   7.0
# 4215         NaN             2          0.0            8                   8.0
# 4216         NaN             2          0.0            9                   9.0
# 4217         NaN             2          0.0           10                  10.0
# 4218         NaN             2          0.0           11                  11.0
# 4220         NaN             2          0.0           13                  13.0
# 4278         NaN             2          0.0            9                   9.0

# %%
df=df[
    df["first_action"] < 2
]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# order_id                     0
# assignment_id                0
# user_id                      0
# assistment_id                0
# problem_id                   0
# original                     0
# correct                      0
# attempt_count                0
# ms_first_response            0
# tutor_mode                   0
# answer_type                  0
# sequence_id                  0
# student_class_id             0
# position                     0
# type                         0
# base_sequence_id             0
# skill_id                 63662
# skill_name               72049
# teacher_id                   0
# school_id                    0
# hint_count                   0
# hint_total                   0
# overlap_time                 0
# template_id                  0
# answer_id               300502
# answer_text              71314
# first_action                 0
# bottom_hint                  0
# opportunity                  0
# opportunity_original     71398
# dtype: int64

# %%
df=df[
    df["first_action"] < 2
]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Handle missing values?

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# order_id                     0
# assignment_id                0
# user_id                      0
# assistment_id                0
# problem_id                   0
# original                     0
# correct                      0
# attempt_count                0
# ms_first_response            0
# tutor_mode                   0
# answer_type                  0
# sequence_id                  0
# student_class_id             0
# position                     0
# type                         0
# base_sequence_id             0
# skill_id                 63662
# skill_name               72049
# teacher_id                   0
# school_id                    0
# hint_count                   0
# hint_total                   0
# overlap_time                 0
# template_id                  0
# answer_id               300502
# answer_text              71314
# first_action                 0
# bottom_hint                  0
# opportunity                  0
# opportunity_original     71398
# dtype: int64

# %%
# Create a clean mapping: one unique numeric ID for each skill_name
skill_name_to_new_id = {
    skill_name: i + 1
    for i, skill_name in enumerate(df['skill_name'].dropna().unique())
}

# Create the new consistent numeric skill ID
df['skill_id_clean'] = df['skill_name'].map(skill_name_to_new_id)

# Check the result
df[['skill_id', 'skill_name', 'skill_id_clean']].drop_duplicates().head(20)
# Out:
#          skill_id                   skill_name  skill_id_clean
# 0            1_13              Box and Whisker             1.0
# 4            1_15              Box and Whisker             1.0
# 160             1              Box and Whisker             1.0
# 3957      2_37_70                 Circle Graph             2.0
# 3963   2_37_48_77                 Circle Graph             2.0
# 3965      2_37_48                 Circle Graph             2.0
# 3969         2_70                 Circle Graph             2.0
# 3976      2_48_79                 Circle Graph             2.0
# 10165           4  Histogram as Table or Graph             3.0
# 11969       5_375                  Number Line             4.0
# 12210       5_102                  Number Line             4.0
# 13864           8                 Scatter Plot             5.0
# 15723        9_14           Stem and Leaf Plot             6.0
# 15724        9_12           Stem and Leaf Plot             6.0
# 15725        9_15           Stem and Leaf Plot             6.0
# 15758        9_13           Stem and Leaf Plot             6.0
# 19551       10_12                        Table             7.0
# 19555       10_13                        Table             7.0
# 19558       10_18                        Table             7.0
# 19559       10_64                        Table             7.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# order_id                     0
# assignment_id                0
# user_id                      0
# assistment_id                0
# problem_id                   0
# original                     0
# correct                      0
# attempt_count                0
# ms_first_response            0
# tutor_mode                   0
# answer_type                  0
# sequence_id                  0
# student_class_id             0
# position                     0
# type                         0
# base_sequence_id             0
# skill_id                 63662
# skill_name               72049
# teacher_id                   0
# school_id                    0
# hint_count                   0
# hint_total                   0
# overlap_time                 0
# template_id                  0
# answer_id               300502
# answer_text              71314
# first_action                 0
# bottom_hint                  0
# opportunity                  0
# opportunity_original     71398
# skill_id_clean           72049
# dtype: int64

# %% [markdown]
# # Data Preprocessing & Feature Engineering
# Transforming, encoding, standardization and preparing features
# - **You only need to outline your approach here. No need to execute**

# %%
# Response time: milliseconds -> seconds
df['response_time_sec'] = df['ms_first_response'] / 1000

# Did the student need more than one attempt?
df['needed_retry'] = (df['attempt_count'] > 1).astype(int)

# Did the student use at least one hint?
df['used_hint'] = (df['hint_count'] > 0).astype(int)

# Correct on first attempt
df['first_try_correct'] = (
    (df['correct'] == 1) &
    (df['attempt_count'] == 1)
).astype(int)

# Percentage of available hints used
df['hint_dependency'] = np.where(
    df['hint_total'] > 0,
    df['hint_count'] / df['hint_total'],
    0
)

# %%
student_skill_df = df.groupby(
    ['user_id', 'skill_id_clean']
).agg(

    # Performance
    accuracy_rate=('correct', 'mean'),
    first_try_success_rate=('first_try_correct', 'mean'),

    # Attempts
    avg_attempts=('attempt_count', 'mean'),
    retry_rate=('needed_retry', 'mean'),

    # Hints
    avg_hints=('hint_count', 'mean'),
    hint_usage_rate=('used_hint', 'mean'),
    bottom_hint_rate=('bottom_hint', 'mean'),
    avg_hint_dependency=('hint_dependency', 'mean'),

    # Response time
    median_response_time=('response_time_sec', 'median'),

    # Practice
    avg_opportunity=('opportunity', 'mean'), # May remove it
    total_interactions=('problem_id', 'count')

).reset_index()

# %%
student_skill_df.head()
# Out:
#    user_id  skill_id_clean  accuracy_rate  first_try_success_rate  \
# 0       14             2.0       0.333333                0.333333
# 1       14            10.0       0.000000                0.000000
# 2       14            11.0       1.000000                1.000000
# 3    21825             7.0       0.666667                0.666667
# 4    21825            63.0       1.000000                1.000000
#
#    avg_attempts  retry_rate  avg_hints  hint_usage_rate  bottom_hint_rate  \
# 0           1.0         0.0   1.444444         0.666667          0.666667
# 1           1.0         0.0   2.500000         1.000000          1.000000
# 2           1.0         0.0   0.000000         0.000000          0.000000
# 3           1.0         0.0   0.000000         0.000000          0.000000
# 4           1.0         0.0   0.000000         0.000000          0.000000
#
#    avg_hint_dependency  median_response_time  avg_opportunity  \
# 0             0.666667               21.8840         5.333333
# 1             1.000000                6.3310         2.500000
# 2             0.000000               11.4170         2.000000
# 3             0.000000               68.9415         3.500000
# 4             0.000000                3.9605         5.500000
#
#    total_interactions
# 0                   9
# 1                   4
# 2                   3
# 3                   6
# 4                  10

# %%
student_skill_df.shape
# Out:
# (34864, 13)

# %%
student_skill_df.isnull().sum()
# Out:
# user_id                   0
# skill_id_clean            0
# accuracy_rate             0
# first_try_success_rate    0
# avg_attempts              0
# retry_rate                0
# avg_hints                 0
# hint_usage_rate           0
# bottom_hint_rate          0
# avg_hint_dependency       0
# median_response_time      0
# avg_opportunity           0
# total_interactions        0
# dtype: int64

# %%
student_skill_df.describe().T
# Out:
#                           count          mean          std   min  \
# user_id                 34864.0  83322.963286  7293.897218  14.0
# skill_id_clean          34864.0     42.377467    24.661440   1.0
# accuracy_rate           34864.0      0.730673     0.314595   0.0
# first_try_success_rate  34864.0      0.723452     0.316829   0.0
# avg_attempts            34864.0      1.777974    17.673643   0.0
# retry_rate              34864.0      0.154461     0.237447   0.0
# avg_hints               34864.0      0.386363     0.871282   0.0
# hint_usage_rate         34864.0      0.131221     0.258269   0.0
# bottom_hint_rate        34864.0      0.088488     0.219842   0.0
# avg_hint_dependency     34864.0      0.109451     0.231287   0.0
# median_response_time    34864.0     43.944644   176.385702   0.0
# avg_opportunity         34864.0      6.266112    23.822524   1.0
# total_interactions      34864.0      7.701210    10.484106   1.0
#
#                                  25%           50%           75%        max
# user_id                 78953.000000  80506.000000  88094.000000  96299.000
# skill_id_clean             23.000000     40.000000     63.000000    101.000
# accuracy_rate               0.571429      0.819347      1.000000      1.000
# first_try_success_rate      0.571429      0.800000      1.000000      1.000
# avg_attempts                1.000000      1.000000      1.400000   1912.500
# retry_rate                  0.000000      0.000000      0.250000      1.000
# avg_hints                   0.000000      0.000000      0.333333      7.000
# hint_usage_rate             0.000000      0.000000      0.142857      1.000
# bottom_hint_rate            0.000000      0.000000      0.000000      1.000
# avg_hint_dependency         0.000000      0.000000      0.100000      1.000
# median_response_time       12.680000     23.844000     45.735500  14920.385
# avg_opportunity             1.500000      3.000000      6.000000   1784.600
# total_interactions          2.000000      5.000000     10.000000    290.000

# %%
student_skill_df = student_skill_df[
    student_skill_df['avg_attempts'] <= 10
]

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    student_skill_df.drop(columns=['user_id', 'skill_id_clean']).corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Between Student-Level Features')
plt.show()

# %%
features = [
    'accuracy_rate',
    'first_try_success_rate',
    'avg_attempts',
    'retry_rate',
    'avg_hints',
    'hint_usage_rate',
    'bottom_hint_rate',
    'avg_hint_dependency',
    'median_response_time',
    'avg_opportunity',
    'total_interactions',
]

student_skill_df[features].hist(
    figsize=(16, 12),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
for col in features:
    plt.figure(figsize=(8, 3))

    sns.boxplot(
        x=student_skill_df[col]
    )

    plt.title(f'Box Plot of {col}')
    plt.show()

# %%
for col in features:
    Q1 = student_skill_df[col].quantile(0.25)
    Q3 = student_skill_df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = student_skill_df[
        (student_skill_df[col] < lower) |
        (student_skill_df[col] > upper)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# accuracy_rate: 0 outliers
# first_try_success_rate: 0 outliers
# avg_attempts: 4404 outliers
# retry_rate: 1722 outliers
# avg_hints: 5437 outliers
# hint_usage_rate: 4534 outliers
# bottom_hint_rate: 8161 outliers
# avg_hint_dependency: 4802 outliers
# median_response_time: 2914 outliers
# avg_opportunity: 2772 outliers
# total_interactions: 2088 outliers

# %% [markdown]
# ## Fix Outliers

# %% [markdown]
# ## a-Transformation

# %%
import myutils
pd.set_option('display.max_colwidth', None)
x, skew_table = myutils.skew_transform(student_skill_df)
skew_table
# Out:
#                    Feature  Original Skewness  \
# 0           skill_id_clean              0.151
# 1            accuracy_rate             -1.139
# 2   first_try_success_rate             -1.097
# 3             avg_attempts              4.615
# 4               retry_rate              1.929
# 5                avg_hints              3.348
# 6          hint_usage_rate              2.300
# 7         bottom_hint_rate              3.019
# 8      avg_hint_dependency              2.619
# 9     median_response_time             64.078
# 10         avg_opportunity             44.174
# 11      total_interactions              5.130
#
#                                                     Transformations  \
# 0                                                              None
# 1                                                           Box-Cox
# 2                                                            Square
# 3                                            Box-Cox -> Yeo-Johnson
# 4                                            Box-Cox -> Square Root
# 5   Yeo-Johnson -> Yeo-Johnson -> Box-Cox -> Box-Cox -> Yeo-Johnson
# 6   Box-Cox -> Yeo-Johnson -> Yeo-Johnson -> Yeo-Johnson -> Box-Cox
# 7   Box-Cox -> Box-Cox -> Yeo-Johnson -> Yeo-Johnson -> Yeo-Johnson
# 8   Yeo-Johnson -> Box-Cox -> Yeo-Johnson -> Box-Cox -> Yeo-Johnson
# 9                                                           Box-Cox
# 10                                                          Box-Cox
# 11                                                          Box-Cox
#
#     Final Skewness  Iterations        Status
# 0            0.151           0    Acceptable
# 1           -0.425           1    Acceptable
# 2           -0.398           1    Acceptable
# 3            0.276           2    Acceptable
# 4            0.329           2    Acceptable
# 5            0.715           5  Still skewed
# 6            0.715           5  Still skewed
# 7            1.245           5  Still skewed
# 8            0.716           5  Still skewed
# 9           -0.021           1    Acceptable
# 10           0.064           1    Acceptable
# 11           0.026           1    Acceptable

# %%
from sklearn.base import BaseEstimator, TransformerMixin


class PositiveShifter(BaseEstimator, TransformerMixin):
    """
    Shifts each column so all values become strictly positive,
    which Box-Cox requires. The shift is learned from the
    training data (fit) and reused unchanged on any other data
    (transform) -- no leakage, no re-computing per call.
    """
    def fit(self, X, y=None):
        X = np.asarray(X, dtype=float)
        col_min = X.min(axis=0)
        self.shift_ = np.where(col_min <= 0, np.abs(col_min) + 1, 0)
        return self

    def transform(self, X):
        X = np.asarray(X, dtype=float)
        return X + self.shift_

# %%
num_box_cox = [
    "accuracy_rate",
    "hint_usage_rate"
]

num_yeojohnson_cols = [
    "avg_attempts",
    "avg_hints",
    "bottom_hint_rate",
    "avg_hint_dependency"
    
]

num_sqaure_cols = [
    "first_try_success_rate"
]

num_sqaureroot_cols = [
    "retry_rate"
]

# %%
num_box_cox_pipeline = Pipeline([
    ("shift", PositiveShifter()),
    ("transformer", PowerTransformer(method="box-cox")),
    ("scaler", StandardScaler())
])

num_yeojohnson_pipeline = Pipeline([
    ("transformer", PowerTransformer(method="yeo-johnson")),
    ("scaler", RobustScaler())
])

num_square_pipeline = Pipeline([
    ("transformer", FunctionTransformer(np.square)),
    ("scaler", RobustScaler())
])

num_sqrt_pipeline = Pipeline([
    ("transformer", FunctionTransformer(np.sqrt)),
    ("scaler", RobustScaler())
])

num_scaler_pipeline = Pipeline([
    ("scaler", RobustScaler())
])

# %%
preprocessor = ColumnTransformer([
    ("box-cox", num_box_cox_pipeline, num_box_cox),
    ("square", num_square_pipeline, num_sqaure_cols),
    ("sqrt", num_sqrt_pipeline, num_sqaureroot_cols),
    ("jeo", num_yeojohnson_pipeline, num_yeojohnson_cols),
], remainder="drop")

# %%
full_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', KMeans(
        n_clusters=3,
        init='k-means++',
        n_init=10,
        max_iter=300,
        random_state=42
    ))
])

# %% [markdown]
# # Modelling Approach

# %% [markdown]
# The project will use **unsupervised clustering models** to identify groups of similar student-skill performance and learning behavior profiles.
#
# * **K-Means Clustering:** The primary model. The optimal number of clusters will be evaluated using the **Elbow Method** and **Silhouette Score**.
# * **Hierarchical Clustering:** A comparison model to examine the hierarchical structure and similarity between student performance profiles.
# * **DBSCAN:** An alternative density-based model that can identify dense groups as well as unusual observations or noise.
